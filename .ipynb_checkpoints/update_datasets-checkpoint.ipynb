# %% [markdown]
# ## Download datasets (CYGNSS and GRDC)

# %% [markdown]
# Importing Packages

# %%
#pip install earthaccess
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ^C
# ERROR: Operation cancelled by user
# Note: you may need to restart the kernel to use updated packages.

# %%
# IMPORT PACKAGES
import earthaccess
import matplotlib.pyplot as plt
import numpy as np
import geopandas as gpd
import xarray as xr
import requests
import os
from tempfile import NamedTemporaryFile
import pandas as pd
import tenacity
print('packages have been imported!')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 5
#       3 import matplotlib.pyplot as plt
#       4 import numpy as np
# ----> 5 import geopandas as gpd
#       6 import xarray as xr
#       7 import requests
#
# File ~/.local/lib/python3.11/site-packages/geopandas/__init__.py:3
#       1 from geopandas._config import options
# ----> 3 from geopandas.geoseries import GeoSeries
#       4 from geopandas.geodataframe import GeoDataFrame
#       5 from geopandas.array import points_from_xy
#
# File ~/.local/lib/python3.11/site-packages/geopandas/geoseries.py:17
#      14 from shapely.geometry.base import BaseGeometry
#      16 import geopandas
# ---> 17 from geopandas.base import GeoPandasBase, _delegate_property
#      18 from geopandas.explore import _explore_geoseries
#      19 from geopandas.plotting import plot_series
#
# File ~/.local/lib/python3.11/site-packages/geopandas/base.py:11
#       8 from shapely.geometry import MultiPoint, box
#       9 from shapely.geometry.base import BaseGeometry
# ---> 11 from . import _compat as compat
#      12 from .array import GeometryArray, GeometryDtype, points_from_xy
#      15 def is_geometry_type(data):
#
# File ~/.local/lib/python3.11/site-packages/geopandas/_compat.py:68
#      64 # -----------------------------------------------------------------------------
#      65 # pyproj compat
#      66 # -----------------------------------------------------------------------------
#      67 try:
# ---> 68     import pyproj  # noqa: F401
#      70     HAS_PYPROJ = True
#      72 except ImportError as err:
#
# File ~/.local/lib/python3.11/site-packages/pyproj/__init__.py:94
#      92 __proj_compiled_version__ = PROJ_COMPILED_VERSION_STR
#      93 try:
# ---> 94     pyproj.network.set_ca_bundle_path()
#      95 except DataDirError as err:
#      96     warnings.warn(str(err))
#
# AttributeError: partially initialized module 'pyproj' has no attribute 'network' (most likely due to a circular import)

# %% [markdown]
# ## 1) CYGNSS

# %%
# Parameters to change
years = [2024, 2020, 2019, 2018, 2017, 2016]
satellite = 'CYGNSS_L3_UC_BERKELEY_WATERMASK_DAILY_V3.2'

#target_dir = f'/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CYGNSS/Data/sls_test'
target_dir = f'/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CYGNSS/Data/sls_CYGNSS_DAILY_WATERMASK/'
# ------------------------------
# Log in, input year to download
print('> logging into earthaccess...')
earthaccess.login()
print('> logged in!')

# %%
# Tenacity logic for exponential backoff (github fix for earthaccess bug)
always_retry = tenacity.retry(wait=tenacity.wait_random_exponential(multiplier=1, max=60))
tenaciously_download_file = always_retry(earthaccess.__store__._download_file)
earthaccess.__store__._download_file = tenaciously_download_file

# Search for files
for year in years:
    earthaccess.login()
    print(f'> querying PACE data, year: {year}...')
    results = earthaccess.search_data(
        short_name = satellite,
        temporal=(f'{year}-01-01',f'{year+1}-01-01'), #Search all data from a given year
        count=600)
    results_df = pd.json_normalize(results) #Print results as a pandas dataframe
    
    # Create dir if doenst exist
    year_dir = os.path.join(target_dir, str(year))
    os.makedirs(year_dir, exist_ok=True)
    
    # Save csv to dir
    csv_path = os.path.join(year_dir, f"{satellite}_{year}_results.csv")
    results_df.to_csv(csv_path, index=False)
    results_df.head()
    
    # Download files
    print(f'Downloading to: {year_dir}')
    print(f'Total files to download: {len(results)}')
    
    # Download all files at once
    print('> downloading PACE data...')
    earthaccess.download(results, year_dir)
    print("> Download completed!")
# Out:
# > querying PACE data, year: 2024...
# Downloading to: /global/scratch/users/cgerlein/fc_ecohydrology_scratch/CYGNSS/Data/sls_CYGNSS_DAILY_WATERMASK/2024
# Total files to download: 367
# > downloading PACE data...
# QUEUEING TASKS | :   0%|          | 0/367 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/367 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/367 [00:00<?, ?it/s]
# > Download completed!
# > querying PACE data, year: 2020...
# Downloading to: /global/scratch/users/cgerlein/fc_ecohydrology_scratch/CYGNSS/Data/sls_CYGNSS_DAILY_WATERMASK/2020
# Total files to download: 367
# > downloading PACE data...
# QUEUEING TASKS | :   0%|          | 0/367 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/367 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/367 [00:00<?, ?it/s]
# > Download completed!
# > querying PACE data, year: 2019...
# Downloading to: /global/scratch/users/cgerlein/fc_ecohydrology_scratch/CYGNSS/Data/sls_CYGNSS_DAILY_WATERMASK/2019
# Total files to download: 366
# > downloading PACE data...
# QUEUEING TASKS | :   0%|          | 0/366 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/366 [00:00<?, ?it/s]

# %%
# Test downloaded scenes
import xarray as xr
test = results_df.iloc[0]['meta.native-id']
test_fn = f'{year_dir}/{test}.nc'
print(test_fn)
test_ds = xr.open_dataset(test_fn)
plt.imshow(test_ds['watermask'])
# Out:
# /global/scratch/users/cgerlein/fc_ecohydrology_scratch/CYGNSS/Data/sls_CYGNSS_DAILY_WATERMASK/2025/cyg.ddmi.2025-01-01.l3.uc-berkeley-watermask-daily.a32.d33.nc

# %% [markdown]
# ## 2) Inspect outputs of CSMUB V2 loop

# %%
daily_dir =  '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/sls_Daily'
monthly_dir = '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/CSV'
masterlist = '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/DATA/GRDC_Stations_UPDATED.csv'
stations_df = pd.read_csv(masterlist)
station_num = stations_df['grdc_no']

n = 481
station_idx=stations_df.iloc[n]['grdc_no']
try: 
    daily_df = pd.read_csv(f'{daily_dir}/{station_idx}_parallel.csv')
except:
    daily_df = pd.read_csv(f'{daily_dir}/{station_idx}_parallel2.csv')
    
monthly_df = pd.read_csv(f'{monthly_dir}/{station_idx}.csv')
# Monthly from daily:
daily_df['Date'] = pd.to_datetime(daily_df['Date'])

# Compute monthly averages from the daily SWE
monthly_avg_from_daily = (
    daily_df
    .set_index('Date')
    .resample('M')['SWE']
    .mean()
    .reset_index()
)
station_dir = '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CYGNSS/Data/sls_GRDC_shp/GRDC_shp'
station_df = pd.read_csv(f'{station_dir}/{station_idx}_Q_Day.Cmd.txt', delimiter=';',encoding='utf-8',skiprows=36)
station_df = station_df[station_df[' Value'] > 0.1]

# Plot
plt.scatter(pd.to_datetime(monthly_avg_from_daily['Date']), monthly_avg_from_daily['SWE'], label = 'Monthly avg from Daily (New)', c ='blue', s = 20
        , zorder = 1)
plt.plot(pd.to_datetime(daily_df['Date']), daily_df['SWE'], label = 'Daily (new)', c = 'blue', alpha = 0.6, lw = 1, zorder = 0)
plt.scatter(pd.to_datetime(monthly_df['Date']), monthly_df['SWE'], label = 'Monthly (Old)', marker = 's', s = 15, c = 'red', zorder = 2)
plt.plot(pd.to_datetime(monthly_df['Date']), monthly_df['SWE'], linestyle = 'dashed', alpha = 0.3, c = 'red', zorder = 2)

plt.xticks(rotation = 45)
plt.legend(loc = 'upper left')
plt.ylabel('SWE')
plt.grid(alpha = 0.3)
plt.title(f'Station {station_idx}')
#plt.ylim(2,daily_df['SWE'].max() + 3)
#plt.ylim(0, 400)
plt.xlim(daily_df['Date'].min(),daily_df['Date'].max())
plt.show()

# %% [markdown]
# ### Lag Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

def getLag (n):
    
    # ========================================
    # Load data
    # ========================================
    daily_dir =  '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/sls_Daily'
    monthly_dir = '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/CSV'
    masterlist = '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/DATA/GRDC_Stations_UPDATED.csv'
    
    stations_df = pd.read_csv(masterlist)
    station_idx = stations_df.iloc[n]['grdc_no']
    
    # Load DAILY SWE
    try:
        daily_df = pd.read_csv(f"{daily_dir}/{station_idx}_parallel.csv")
    except:
        daily_df = pd.read_csv(f"{daily_dir}/{station_idx}_parallel2.csv")
    
    daily_df['Date'] = pd.to_datetime(daily_df['Date'])
    daily_df = daily_df[daily_df['SWE'] > 0]   # remove zeros
    
    
    # Load MONTHLY SWE (correct timing)
    monthly_df = pd.read_csv(f"{monthly_dir}/{station_idx}.csv")
    monthly_df['Date'] = pd.to_datetime(monthly_df['Date'])
    monthly_df = monthly_df[monthly_df['SWE'] > 0]
    # Create a daily timeline covering the daily SWE range
    date_range = pd.date_range(
        start=daily_df['Date'].min(),
        end=daily_df['Date'].max(),
        freq='D'
    )
    
    # Reindex monthly to daily by forward-filling inside each month
    monthly_daily = (
        monthly_df.set_index('Date')
        .resample('D')
        .ffill()
        .reindex(date_range)
        .ffill()
        .reset_index()
    )
    monthly_daily.head()
    monthly_daily = monthly_daily.rename(columns={"index": "Date"})
    monthly_daily.head()
    
    df = pd.merge(
        daily_df[['Date','SWE']], 
        monthly_daily,
        on='Date',
        how='inner'
    )
    df.head() # x is daily, y is monthly
    df.rename(columns={'SWE_x': 'SWE_daily', 'SWE_y': 'SWE_monthly'}, inplace=True)
    
    def normalize(x):
        return (x - x.min()) / (x.max() - x.min())
    
    df['daily_norm'] = normalize(df['SWE_daily'])
    df['monthly_norm'] = normalize(df['SWE_monthly'])
    df.head()
    return(df)

# %%
import pandas as pd

# Create empty list to hold dicts for each station
lag_records = []

numbers = range(580)
for n in numbers:
    try:
        df = getLag(n)
        
        # Lag analysis
        x = df['daily_norm'].values
        y = df['monthly_norm'].values
        corr = np.correlate(x - x.mean(), y - y.mean(), mode='full')
        lags = np.arange(-len(x)+1, len(x))
        
        valid_mask = (lags >= 0) & (lags <= 20)
        valid_lags = lags[valid_mask]
        valid_corr = corr[valid_mask]
        
        best_lag_days = valid_lags[np.argmax(valid_corr)]
        print(f"{n} Estimated lag: {best_lag_days} days")
        
        # Append as dict
        lag_records.append({"station_index": n, "best_lag_days": best_lag_days})
        
    except Exception as e:
        print(f"Station {n} failed: {e}")
        continue

# Convert to DataFrame
lag_df = pd.DataFrame(lag_records)
lag_df['station_number'] = lag_df['station_index'].map(station_num)
print(lag_df.head())
# Out:
# Station 0 failed: [Errno 2] No such file or directory: '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/
# 94 Estimated lag: 20 days
# 95 Estimated lag: 16 days
# 96 Estimated lag: 0 days
# 97 Estimated lag: 20 days
# 98 Estimated lag: 20 days
# 99 Estimated lag: 0 days
# 100 Estimated lag: 6 days
# 101 Estimated lag: 12 days
# 102 Estimated lag: 14 days
# 103 Estimated lag: 7 days
# 104 Estimated lag: 17 days
# 105 Estimated lag: 20 days
# 106 Estimated lag: 8 days
# 107 Estimated lag: 9 days
# 108 Estimated lag: 11 days
# 109 Estimated lag: 9 days
# 110 Estimated lag: 10 days
# 111 Estimated lag: 3 days
# 112 Estimated lag: 20 days
# 113 Estimated lag: 19 days
# 114 Estimated lag: 1 days
# 115 Estimated lag: 11 days
# 116 Estimated lag: 11 days
# 117 Estimated lag: 0 days
# 118 Estimated lag: 11 days
# 119 Estimated lag: 0 days
# 120 Estimated lag: 0 days
# 121 Estimated lag: 0 days
# 122 Estimated lag: 4 days
# 123 Estimated lag: 0 days
# 124 Estimated lag: 0 days
# 125 Estimated lag: 0 days
# 126 Estimated lag: 1 days
# Station 127 failed: Neither `start` nor `end` can be NaT
# Station 128 failed: Neither `start` nor `end` can be NaT
# Station 129 failed: Neither `start` nor `end` can be NaT
# Station 130 failed: Neither `start` nor `end` can be NaT
# Station 131 failed: Neither `start` nor `end` can be NaT
# Station 132 failed: Neither `start` nor `end` can be NaT
# Station 133 failed: Neither `start` nor `end` can be NaT
# Station 134 failed: Neither `start` nor `end` can be NaT
# Station 135 failed: Neither `start` nor `end` can be NaT
# Station 136 failed: Neither `start` nor `end` can be NaT
# Station 137 failed: Neither `start` nor `end` can be NaT
# 138 Estimated lag: 0 days
# 139 Estimated lag: 11 days
# 140 Estimated lag: 13 days
# 141 Estimated lag: 16 days
# 142 Estimated lag: 15 days
# 143 Estimated lag: 14 days
# 144 Estimated lag: 13 days
# 145 Estimated lag: 14 days
# 146 Estimated lag: 13 days
# 147 Estimated lag: 16 days
# 148 Estimated lag: 12 days
# 149 Estimated lag: 12 days
# 150 Estimated lag: 0 days
# 151 Estimated lag: 16 days
# 152 Estimated lag: 5 days
# 153 Estimated lag: 17 days
# 154 Estimated lag: 20 days
# 155 Estimated lag: 20 days
# 156 Estimated lag: 15 days
# 157 Estimated lag: 5 days
# 158 Estimated lag: 20 days
# 159 Estimated lag: 20 days
# 160 Estimated lag: 20 days
# 161 Estimated lag: 18 days
# 162 Estimated lag: 20 days
# 163 Estimated lag: 8 days
# 164 Estimated lag: 9 days
# 165 Estimated lag: 13 days
# 166 Estimated lag: 20 days
# 167 Estimated lag: 11 days
# 168 Estimated lag: 15 days
# 169 Estimated lag: 13 days
# 170 Estimated lag: 20 days
# 171 Estimated lag: 11 days
# 172 Estimated lag: 16 days
# 173 Estimated lag: 20 days
# 174 Estimated lag: 16 days
# 175 Estimated lag: 12 days
# 176 Estimated lag: 13 days
# 177 Estimated lag: 11 days
# 178 Estimated lag: 17 days
# 179 Estimated lag: 14 days
# 180 Estimated lag: 16 days
# 181 Estimated lag: 19 days
# 182 Estimated lag: 20 days
# 183 Estimated lag: 20 days
# 184 Estimated lag: 16 days
# 185 Estimated lag: 20 days
# 186 Estimated lag: 20 days
# 488 Estimated lag: 12 days
# 489 Estimated lag: 2 days
# 490 Estimated lag: 14 days
# 491 Estimated lag: 16 days
# 492 Estimated lag: 10 days
# 493 Estimated lag: 8 days
# 494 Estimated lag: 10 days
# 495 Estimated lag: 9 days
# 496 Estimated lag: 10 days
# 497 Estimated lag: 8 days
# 498 Estimated lag: 5 days
# 499 Estimated lag: 10 days
# 500 Estimated lag: 11 days
# 501 Estimated lag: 14 days
# 502 Estimated lag: 17 days
# 503 Estimated lag: 16 days
# 504 Estimated lag: 5 days
# 505 Estimated lag: 10 days
# 506 Estimated lag: 20 days
# 507 Estimated lag: 13 days
# 508 Estimated lag: 0 days
# 509 Estimated lag: 12 days
# 510 Estimated lag: 9 days
# 511 Estimated lag: 0 days
# 512 Estimated lag: 10 days
# 513 Estimated lag: 15 days
# 514 Estimated lag: 11 days
# 515 Estimated lag: 10 days
# 516 Estimated lag: 15 days
# 517 Estimated lag: 12 days
# 518 Estimated lag: 14 days
# 519 Estimated lag: 13 days
# 520 Estimated lag: 12 days
# 521 Estimated lag: 13 days
# 522 Estimated lag: 0 days
# 523 Estimated lag: 18 days
# 524 Estimated lag: 10 days
# 525 Estimated lag: 19 days
# 526 Estimated lag: 20 days
# 527 Estimated lag: 0 days
# 528 Estimated lag: 12 days
# 529 Estimated lag: 9 days
# 530 Estimated lag: 14 days
# 531 Estimated lag: 12 days
# 532 Estimated lag: 12 days
# 533 Estimated lag: 0 days
# 534 Estimated lag: 15 days
# 535 Estimated lag: 15 days
# 536 Estimated lag: 12 days
# Station 537 failed: [Errno 2] No such file or directory: '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/sls_Daily/5204252_parallel2.csv'
# 538 Estimated lag: 12 days
# Station 539 failed: [Errno 2] No such file or directory: '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/sls_Daily/5204268_parallel2.csv'
# 540 Estimated lag: 10 days
# 541 Estimated lag: 11 days
# 542 Estimated lag: 6 days
# 543 Estimated lag: 12 days
# 544 Estimated lag: 11 days
# 545 Estimated lag: 13 days
# 546 Estimated lag: 12 days
# Station 547 failed: [Errno 2] No such file or directory: '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/sls_Daily/5404270_parallel2.csv'
# Station 548 failed: [Errno 2] No such file or directory: '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/sls_Daily/5404271_parallel2.csv'
# 549 Estimated lag: 0 days
# 550 Estimated lag: 0 days
# 551 Estimated lag: 0 days
# 552 Estimated lag: 13 days
# 553 Estimated lag: 11 days
# 554 Estimated lag: 20 days
# 555 Estimated lag: 0 days
# Station 556 failed: [Errno 2] No such file or directory: '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/sls_Daily/5607023_parallel2.csv'
# Station 557 failed: [Errno 2] No such file or directory: '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/sls_Daily/5607024_parallel2.csv'
# Station 558 failed: [Errno 2] No such file or directory: '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/sls_Daily/5607025_parallel2.csv'
# Station 559 failed: [Errno 2] No such file or directory: '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/sls_Daily/5607200_parallel2.csv'
# Station 560 failed: [Errno 2] No such file or directory: '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/sls_Daily/5607201_parallel2.csv'
# Station 561 failed: [Errno 2] No such file or directory: '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/sls_Daily/5607400_parallel2.csv'
# Station 562 failed: [Errno 2] No such file or directory: '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/sls_Daily/5607410_parallel2.csv'
# Station 563 failed: [Errno 2] No such file or directory: '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/sls_Daily/5607500_parallel2.csv'
# Station 564 failed: [Errno 2] No such file or directory: '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/sls_Daily/5607520_parallel2.csv'
# Station 565 failed: [Errno 2] No such file or directory: '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/sls_Daily/5608095_parallel2.csv'
# Station 566 failed: [Errno 2] No such file or directory: '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/sls_Daily/5608096_parallel2.csv'
# Station 567 failed: [Errno 2] No such file or directory: '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/sls_Daily/5708094_parallel2.csv'
# Station 568 failed: [Errno 2] No such file or directory: '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/sls_Daily/5708110_parallel2.csv'
# Station 569 failed: [Errno 2] No such file or directory: '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/sls_Daily/5708126_parallel2.csv'
# Station 570 failed: [Errno 2] No such file or directory: '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/sls_Daily/5708141_parallel2.csv'
# Station 571 failed: [Errno 2] No such file or directory: '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/sls_Daily/5708142_parallel2.csv'
# Station 572 failed: [Errno 2] No such file or directory: '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/sls_Daily/5708145_parallel2.csv'
# Station 573 failed: [Errno 2] No such file or directory: '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/sls_Daily/5708148_parallel2.csv'
# Station 574 failed: [Errno 2] No such file or directory: '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/sls_Daily/5709100_parallel2.csv'
# Station 575 failed: [Errno 2] No such file or directory: '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/sls_Daily/5709105_parallel2.csv'
# Station 576 failed: [Errno 2] No such file or directory: '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/sls_Daily/5709110_parallel2.csv'
# Station 577 failed: [Errno 2] No such file or directory: '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/sls_Daily/5709112_parallel2.csv'
# Station 578 failed: single positional indexer is out-of-bounds
# Station 579 failed: single positional indexer is out-of-bounds
#    station_index  best_lag_days  station_number
# 0              2             12         1159105
# 1              3             20         1159125
# 2              4             15         1159130
# 3              5             12         1159290
# 4              6             12         1159300

# %%
n = 4
df = getLag(n)
# Lag analysis --------------
x = df['daily_norm'].values
y = df['monthly_norm'].values
corr = np.correlate(x - x.mean(), y - y.mean(), mode='full')
lags = np.arange(-len(x)+1, len(x))
# Lag calc
valid_mask = (lags >= 0) & (lags <= 20)
valid_lags = lags[valid_mask]
valid_corr = corr[valid_mask]
best_lag_days = valid_lags[np.argmax(valid_corr)]
print(f"{(n)} Estimated lag: {best_lag_days} days")
#lag_list.append(best_lag_days)
# Plot it
df['daily_norm_shifted'] = df['daily_norm'].shift(-best_lag_days)
df_shift = df.dropna(subset=['daily_norm_shifted'])
plt.figure(figsize=(12,5))
plt.plot(df['Date'], df['monthly_norm'], label='Monthly SWE (normalized)', lw=2, c = 'b')
plt.plot(df['Date'], df['daily_norm'], label='Daily SWE (normalized)', lw=1, alpha=0.5, c = 'black')
plt.plot(df_shift['Date'], df_shift['daily_norm_shifted'],
         label=f'Daily SWE shifted by {best_lag_days} days', c = 'r', linestyle='-', lw=2)
plt.legend()
plt.grid(alpha=0.3)
plt.title(f"Station {station_idx} – Daily Lag Analysis")
plt.ylabel("Normalized SWE (0–1)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig(f"/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/lag_analysis/lag_plot_station_{station_idx}.pdf", 
            format='pdf', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# 4 Estimated lag: 15 days

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define integer bins
bins = range(int(lag_df['best_lag_days'].min()), int(lag_df['best_lag_days'].max()) + 2)

lag_df['best_lag_days'].hist(bins=bins, edgecolor='black', zorder=2)

plt.xlabel('Estimated Lag Time (days)')
plt.ylabel('Occurrences')
plt.grid(alpha=0.5, zorder=0)
plt.title(f'Numpy correlation estimated time lag\nDaily vs. Monthly CYGNSS SWE\n{len(lag_df)} stations')

# Set x-ticks at every integer (or change step to 2, 3, etc.)
plt.xticks(np.arange(lag_df['best_lag_days'].min(), lag_df['best_lag_days'].max() + 1, 2))

plt.show()

# %%
# Cross corr plot
plt.figure(figsize=(10,4))
plt.plot(valid_lags, valid_corr, marker='o')
plt.axvline(best_lag_days, color='r', linestyle='--', label=f'Max corr at {best_lag_days} days')
plt.xlabel('Lag (days)')
plt.ylabel('Cross-correlation')
plt.title(f'Station {station_idx} – Lag vs. Cross-correlation')
plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Merge for lag
stations_loc = stations_df[['grdc_no', 'lat', 'long']]
lag_df_coords = lag_df.merge(
    stations_loc, 
    left_on='station_number', 
    right_on='grdc_no', 
    how='left'
)

# Optional: drop redundant 'grdc_no' column if desired
lag_df_coords = lag_df_coords.drop(columns=['grdc_no'])

# Reorder columns nicely
lag_df_coords = lag_df_coords[['station_index', 'station_number', 'lat', 'long', 'best_lag_days']]

lag_df_coords
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Merge for lag
# ----> 2 stations_loc = stations_df[['grdc_no', 'lat', 'long']]
#       3 lag_df_coords = lag_df.merge(
#       4     stations_loc,
#       5     left_on='station_number',
#       6     right_on='grdc_no',
#       7     how='left'
#       8 )
#      10 # Optional: drop redundant 'grdc_no' column if desired
#
# NameError: name 'stations_df' is not defined

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
url = "https://raw.githubusercontent.com/datasets/geo-countries/master/data/countries.geojson"
world = gpd.read_file(url)
gdf = gpd.GeoDataFrame(
    lag_df_coords,
    geometry=gpd.points_from_xy(lag_df_coords['long'], lag_df_coords['lat']),
    crs="EPSG:4326"
)
# Plot
fig, ax = plt.subplots(figsize=(12,6))
world.plot(ax=ax, color='lightgray', edgecolor='black')

gdf.plot(
    ax=ax,
    column='best_lag_days',
    cmap='viridis',
    markersize=40,
    legend=True,
    #edgecolor='k',
    alpha=0.8
)

plt.title('Station Estimated Lag Times')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
# Find missing stations
daily_dir = '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/sls_Daily'
masterlist = '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/DATA/GRDC_Stations_UPDATED.csv'
daily_files = os.listdir(daily_dir)
station_ids = set(stations_df['grdc_no'].astype(str))
daily_station_ids = {
    f.split("_")[0]  
    for f in daily_files
    if f.endswith(".csv")
}
daily_done = daily_station_ids.intersection(station_ids)
missing_in_daily = station_ids - daily_done
missing_in_daily
# Out:
# {'1159100',
#  '1159103',
#  '5204252',
#  '5204268',
#  '5404270',
#  '5404271',
#  '5607500',
#  '5708110'}

# %%
missing_in_daily_int = {int(x) for x in missing_in_daily}
indices = stations_df.index[stations_df['grdc_no'].isin(missing_in_daily_int)].tolist()
indices
# Out:
# [0, 1, 537, 539, 547, 548, 563, 568]
