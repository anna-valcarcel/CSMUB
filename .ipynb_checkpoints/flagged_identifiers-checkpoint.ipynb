# %%
import shutil
import os
import pandas as pd

# %%
masterfile = "/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/delineation_stats.csv"
df = pd.read_csv(masterfile)

print(df.columns)
# Out:
# Index(['Unnamed: 0', 'Country', 'Station', 'Index', 'lat', 'lon', 'lat_snap_y',
#        'lon_snap_x', 'area_grdc_km2', 'area_delineated_km2',
#        'area_intersect_km2', 'pct_intersect', 'avg_acc_of_full_area',
#        'img_path', 'flow_accum_at_pour_pt', 'snapped_accum', 'max_accum',
#        'avg_accum', 'win_shape', 'max_accum_9x9', 'avg_accum_9x9',
#        'estimated_distance_km', 'FLAG_small_areaDelin<1000',
#        'FLAG_small_snapAcc<100', 'FLAG_small_Intersec<90',
#        'FLAG_cropping_GRDC>cropDEM'],
#       dtype='object')

# %%
indx = df.index[df['FLAG_small_areaDelin<1000'] == True].tolist()
print(len(indx))
# Out:
# 25

# %%
stations = df['Station'][indx]
station_nums = [str(x) for x in stations]

# %%
source_folder_path = "/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/intersection_delin_plots/"  # Replace with your source folder path
destination_folder_path = "/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/intersection_delin_plots/small_area_delin/"  # Replace with your destination folder path

# Ensure the destination folder exists
os.makedirs(destination_folder_path, exist_ok=True)

# Iterate through files in the source folder and copy them
for station in station_nums:
    for filename in os.listdir(source_folder_path):
        if station in filename:
            source_file_path = os.path.join(source_folder_path, filename)
            destination_file_path = os.path.join(destination_folder_path, filename)
    
            # Check if it's a file before copying (to avoid copying subdirectories)
            if os.path.isfile(source_file_path):
                shutil.copy(source_file_path, destination_file_path)
                print(f"File '{filename}' copied to '{destination_folder_path}'")
# Out:
# File '1992850_115.png' copied to '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/intersection_delin_plots/small_area_delin/'
# File '2260500_122.png' copied to '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/intersection_delin_plots/small_area_delin/'
# File '3179800_148.png' copied to '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/intersection_delin_plots/small_area_delin/'
# File '3265601_157.png' copied to '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/intersection_delin_plots/small_area_delin/'
# File '3629001_203.png' copied to '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/intersection_delin_plots/small_area_delin/'
# File '3649460_288.png' copied to '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/intersection_delin_plots/small_area_delin/'
# File '3652890_333.png' copied to '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/intersection_delin_plots/small_area_delin/'
# File '4125900_369.png' copied to '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/intersection_delin_plots/small_area_delin/'
# File '4126701_378.png' copied to '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/intersection_delin_plots/small_area_delin/'
# File '4148720_411.png' copied to '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/intersection_delin_plots/small_area_delin/'
# File '4149632_428.png' copied to '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/intersection_delin_plots/small_area_delin/'
# File '4150450_444.png' copied to '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/intersection_delin_plots/small_area_delin/'
# File '4152050_474.png' copied to '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/intersection_delin_plots/small_area_delin/'
# File '4152465_483.png' copied to '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/intersection_delin_plots/small_area_delin/'
# File '5104245_501.png' copied to '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/intersection_delin_plots/small_area_delin/'
# File '5109110_502.png' copied to '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/intersection_delin_plots/small_area_delin/'
# File '5110020_511.png' copied to '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/intersection_delin_plots/small_area_delin/'
# File '5204101_520.png' copied to '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/intersection_delin_plots/small_area_delin/'
# File '5204250_528.png' copied to '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/intersection_delin_plots/small_area_delin/'
# File '5204300_533.png' copied to '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/intersection_delin_plots/small_area_delin/'
# File '5204450_537.png' copied to '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/intersection_delin_plots/small_area_delin/'
# File '5204452_539.png' copied to '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/intersection_delin_plots/small_area_delin/'
# File '5204460_540.png' copied to '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/intersection_delin_plots/small_area_delin/'
# File '5410100_545.png' copied to '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/intersection_delin_plots/small_area_delin/'
# File '5607200_555.png' copied to '/global/scratch/users/cgerlein/fc_ecohydrology_scratch/CSMUB/RESULTS/intersection_delin_plots/small_area_delin/'
