# %%
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report
from tensorflow.python import keras
from tensorflow.keras import layers
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import SimpleRNN , Input,Flatten, LSTM
from tensorflow.keras import backend as K
from keras import initializers
from tensorflow.keras import optimizers
from tensorflow.keras.optimizers import SGD
from keras.optimizers import Adam
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import pandas as pd
import os
import numpy as np

# %%
opened = []

csv_path = '/global/scratch/users/arvalcarcel/CSMUB/RESULTS/CSV/'

masterlist = '/global/scratch/users/arvalcarcel/CSMUB/RESULTS/ALL_STATIONS_FINAL_REVISED.csv'

stations_df = pd.read_csv(masterlist)
station_num = stations_df['grdc_no']

arrayFile = [os.path.join(csv_path, f"{station_no}.csv") for station_no in station_num]

for file in arrayFile:
  df = pd.read_csv(file, index_col= None, header = 0)
  opened.append(df)

total_df = pd.concat(opened, axis = 0, ignore_index = True)

q = total_df['Q']
print(min(q),max(q))
swe = total_df['SWE']
scaled = total_df['SWE_scaled']/100
print(min(scaled),max(scaled))
# Out:
# 0.0 259209.349
# 0.0 428837.68444948917

# %%
plt.scatter(scaled,q)
plt.title('Raw Data - All Basins')
plt.xlabel('Surface Water Extent Area [km2]')
plt.ylabel('Streamflow [m3/s]')
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LeakyReLU

# Convert q and swe to NumPy arrays
X = scaled.to_numpy()  # This will be 1D: shape (num_samples,)
y = q.to_numpy()

# Assume X and y are your 1D time series arrays
# Step 1: Replace zeros with a small value
X[X == 0] = 1e-9
y[y == 0] = 1e-9

# Step 2: Reshape data (if needed)
X = X.reshape(-1, 1)
y = y.reshape(-1, 1)

# Step 3: Scale the data
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y)

# Step 4: Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, random_state=42)

# %%
# Step 4: Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, random_state=42)

# %%
# model = Sequential([
#     Dense(256, input_dim=1, activation='tanh'),
#     Dense(128, activation='elu'),
#     Dense(64, activation='relu'),
#     # LeakyReLU(alpha=0.01),
#     Dense(32, activation='relu'),
#     Dense(1, activation='linear')])

# model.compile(optimizer=Adam(learning_rate=1e-3), 
#           loss='mean_squared_error',
#           metrics=['mae','accuracy'])

# history = model.fit(X_train, y_train, epochs=500, 
#             batch_size=512, validation_data=(X_test, y_test), 
#             verbose=1)

model = Sequential([
    Dense(256, input_dim=1, activation='tanh'),
    Dense(128, activation='elu'),
    Dense(64, activation='relu'),
    Dense(32, activation=LeakyReLU(alpha=0.01)),  # LeakyReLU layer
    Dense(1, activation='linear')                # Output layer
])

from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

model.compile(optimizer=Adam(learning_rate=1e-4), 
              loss='mean_squared_error',
              metrics=['mae','accuracy'])
# Out:
# Epoch 1/500
# /global/home/users/arvalcarcel/.local/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0641 - loss: 3.9441e-04 - mae: 0.0061 - val_accuracy: 0.0772 - val_loss: 3.6104e-04 - val_mae: 0.0041
# Epoch 2/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0644 - loss: 3.7160e-04 - mae: 0.0039 - val_accuracy: 0.0774 - val_loss: 3.9968e-04 - val_mae: 0.0048
# Epoch 3/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0657 - loss: 3.9803e-04 - mae: 0.0040 - val_accuracy: 0.0772 - val_loss: 3.5101e-04 - val_mae: 0.0036
# Epoch 4/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0654 - loss: 3.4477e-04 - mae: 0.0035 - val_accuracy: 0.0772 - val_loss: 3.5104e-04 - val_mae: 0.0032
# Epoch 5/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0674 - loss: 4.2489e-04 - mae: 0.0043 - val_accuracy: 0.0772 - val_loss: 4.1329e-04 - val_mae: 0.0057
# Epoch 6/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0667 - loss: 4.5179e-04 - mae: 0.0050 - val_accuracy: 0.0772 - val_loss: 3.3417e-04 - val_mae: 0.0035
# Epoch 7/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0684 - loss: 3.6443e-04 - mae: 0.0037 - val_accuracy: 0.0772 - val_loss: 3.4516e-04 - val_mae: 0.0040
# Epoch 8/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0671 - loss: 3.2395e-04 - mae: 0.0038 - val_accuracy: 0.0772 - val_loss: 3.2991e-04 - val_mae: 0.0037
# Epoch 9/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0675 - loss: 3.8327e-04 - mae: 0.0043 - val_accuracy: 0.0772 - val_loss: 4.1886e-04 - val_mae: 0.0045
# Epoch 10/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0652 - loss: 3.5860e-04 - mae: 0.0041 - val_accuracy: 0.0772 - val_loss: 3.4218e-04 - val_mae: 0.0035
# Epoch 11/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0668 - loss: 3.4924e-04 - mae: 0.0043 - val_accuracy: 0.0772 - val_loss: 3.6373e-04 - val_mae: 0.0038
# Epoch 12/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0687 - loss: 3.5851e-04 - mae: 0.0041 - val_accuracy: 0.0772 - val_loss: 3.4311e-04 - val_mae: 0.0041
# Epoch 13/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0690 - loss: 3.9703e-04 - mae: 0.0044 - val_accuracy: 0.0772 - val_loss: 3.2793e-04 - val_mae: 0.0032
# Epoch 14/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0667 - loss: 3.6171e-04 - mae: 0.0037 - val_accuracy: 0.0772 - val_loss: 3.3491e-04 - val_mae: 0.0053
# Epoch 15/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0651 - loss: 3.2895e-04 - mae: 0.0044 - val_accuracy: 0.0774 - val_loss: 3.1073e-04 - val_mae: 0.0038
# Epoch 16/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0641 - loss: 3.5964e-04 - mae: 0.0038 - val_accuracy: 0.0774 - val_loss: 3.0832e-04 - val_mae: 0.0039
# Epoch 17/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0670 - loss: 2.7202e-04 - mae: 0.0037 - val_accuracy: 0.0774 - val_loss: 2.9891e-04 - val_mae: 0.0039
# Epoch 18/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0646 - loss: 3.2908e-04 - mae: 0.0038 - val_accuracy: 0.0772 - val_loss: 3.0350e-04 - val_mae: 0.0049
# Epoch 19/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0646 - loss: 3.1936e-04 - mae: 0.0042 - val_accuracy: 0.0772 - val_loss: 3.6206e-04 - val_mae: 0.0039
# Epoch 20/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0659 - loss: 4.1362e-04 - mae: 0.0045 - val_accuracy: 0.0774 - val_loss: 2.9396e-04 - val_mae: 0.0038
# Epoch 21/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0684 - loss: 3.3865e-04 - mae: 0.0044 - val_accuracy: 0.0774 - val_loss: 3.0279e-04 - val_mae: 0.0047
# Epoch 22/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0665 - loss: 3.1015e-04 - mae: 0.0042 - val_accuracy: 0.0774 - val_loss: 2.7234e-04 - val_mae: 0.0054
# Epoch 23/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0663 - loss: 2.8407e-04 - mae: 0.0048 - val_accuracy: 0.0774 - val_loss: 2.4130e-04 - val_mae: 0.0032
# Epoch 24/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0650 - loss: 3.1979e-04 - mae: 0.0039 - val_accuracy: 0.0772 - val_loss: 3.1251e-04 - val_mae: 0.0029
# Epoch 25/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0679 - loss: 3.1633e-04 - mae: 0.0043 - val_accuracy: 0.0774 - val_loss: 2.7560e-04 - val_mae: 0.0035
# Epoch 26/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0684 - loss: 3.3529e-04 - mae: 0.0046 - val_accuracy: 0.0774 - val_loss: 3.0562e-04 - val_mae: 0.0095
# Epoch 27/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0652 - loss: 2.5147e-04 - mae: 0.0059 - val_accuracy: 0.0774 - val_loss: 2.4974e-04 - val_mae: 0.0055
# Epoch 28/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0683 - loss: 2.5974e-04 - mae: 0.0044 - val_accuracy: 0.0774 - val_loss: 2.2477e-04 - val_mae: 0.0038
# Epoch 29/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0669 - loss: 2.5630e-04 - mae: 0.0042 - val_accuracy: 0.0774 - val_loss: 3.9693e-04 - val_mae: 0.0096
# Epoch 30/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0667 - loss: 3.9622e-04 - mae: 0.0069 - val_accuracy: 0.0774 - val_loss: 2.3206e-04 - val_mae: 0.0031
# Epoch 31/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0683 - loss: 3.0359e-04 - mae: 0.0042 - val_accuracy: 0.0774 - val_loss: 2.1300e-04 - val_mae: 0.0038
# Epoch 32/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0684 - loss: 2.9479e-04 - mae: 0.0043 - val_accuracy: 0.0774 - val_loss: 2.1267e-04 - val_mae: 0.0038
# Epoch 33/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0674 - loss: 2.1675e-04 - mae: 0.0034 - val_accuracy: 0.0774 - val_loss: 2.1787e-04 - val_mae: 0.0029
# Epoch 34/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0662 - loss: 2.8753e-04 - mae: 0.0038 - val_accuracy: 0.0774 - val_loss: 2.3251e-04 - val_mae: 0.0048
# Epoch 35/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0706 - loss: 2.7575e-04 - mae: 0.0040 - val_accuracy: 0.0774 - val_loss: 2.3001e-04 - val_mae: 0.0051
# Epoch 36/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0656 - loss: 2.7500e-04 - mae: 0.0046 - val_accuracy: 0.0774 - val_loss: 2.2043e-04 - val_mae: 0.0047
# Epoch 37/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0668 - loss: 2.2671e-04 - mae: 0.0040 - val_accuracy: 0.0774 - val_loss: 2.4693e-04 - val_mae: 0.0085
# Epoch 38/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0687 - loss: 2.4472e-04 - mae: 0.0063 - val_accuracy: 0.0774 - val_loss: 3.0601e-04 - val_mae: 0.0050
# Epoch 39/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0671 - loss: 3.0157e-04 - mae: 0.0046 - val_accuracy: 0.0774 - val_loss: 2.4362e-04 - val_mae: 0.0034
# Epoch 40/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0646 - loss: 2.4711e-04 - mae: 0.0036 - val_accuracy: 0.0774 - val_loss: 2.7613e-04 - val_mae: 0.0040
# Epoch 41/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0679 - loss: 2.5929e-04 - mae: 0.0048 - val_accuracy: 0.0774 - val_loss: 2.4022e-04 - val_mae: 0.0036
# Epoch 42/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0662 - loss: 2.4926e-04 - mae: 0.0038 - val_accuracy: 0.0774 - val_loss: 2.1718e-04 - val_mae: 0.0056
# Epoch 43/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0679 - loss: 2.6369e-04 - mae: 0.0041 - val_accuracy: 0.0774 - val_loss: 2.5495e-04 - val_mae: 0.0033
# Epoch 44/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0641 - loss: 2.3217e-04 - mae: 0.0034 - val_accuracy: 0.0774 - val_loss: 2.3570e-04 - val_mae: 0.0039
# Epoch 45/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0653 - loss: 2.5040e-04 - mae: 0.0051 - val_accuracy: 0.0774 - val_loss: 2.0900e-04 - val_mae: 0.0038
# Epoch 46/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0657 - loss: 2.3972e-04 - mae: 0.0037 - val_accuracy: 0.0774 - val_loss: 2.2767e-04 - val_mae: 0.0039
# Epoch 47/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0649 - loss: 2.1181e-04 - mae: 0.0038 - val_accuracy: 0.0774 - val_loss: 2.2977e-04 - val_mae: 0.0053
# Epoch 48/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0654 - loss: 2.6840e-04 - mae: 0.0044 - val_accuracy: 0.0774 - val_loss: 2.3988e-04 - val_mae: 0.0028
# Epoch 49/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0688 - loss: 2.6500e-04 - mae: 0.0035 - val_accuracy: 0.0774 - val_loss: 2.5536e-04 - val_mae: 0.0057
# Epoch 50/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0653 - loss: 2.2386e-04 - mae: 0.0039 - val_accuracy: 0.0774 - val_loss: 2.3068e-04 - val_mae: 0.0059
# Epoch 51/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0664 - loss: 2.4456e-04 - mae: 0.0047 - val_accuracy: 0.0774 - val_loss: 3.1064e-04 - val_mae: 0.0056
# Epoch 52/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0684 - loss: 3.2716e-04 - mae: 0.0076 - val_accuracy: 0.0774 - val_loss: 2.6219e-04 - val_mae: 0.0034
# Epoch 53/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0646 - loss: 2.4669e-04 - mae: 0.0034 - val_accuracy: 0.0774 - val_loss: 2.4656e-04 - val_mae: 0.0057
# Epoch 54/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0673 - loss: 2.5239e-04 - mae: 0.0043 - val_accuracy: 0.0774 - val_loss: 2.1738e-04 - val_mae: 0.0040
# Epoch 55/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0670 - loss: 2.3793e-04 - mae: 0.0037 - val_accuracy: 0.0774 - val_loss: 2.1392e-04 - val_mae: 0.0033
# Epoch 56/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0655 - loss: 2.3824e-04 - mae: 0.0036 - val_accuracy: 0.0774 - val_loss: 2.1953e-04 - val_mae: 0.0036
# Epoch 57/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0678 - loss: 2.6577e-04 - mae: 0.0035 - val_accuracy: 0.0774 - val_loss: 2.0833e-04 - val_mae: 0.0030
# Epoch 58/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0679 - loss: 2.7872e-04 - mae: 0.0035 - val_accuracy: 0.0774 - val_loss: 2.1884e-04 - val_mae: 0.0028
# Epoch 59/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0644 - loss: 2.5193e-04 - mae: 0.0034 - val_accuracy: 0.0774 - val_loss: 2.2892e-04 - val_mae: 0.0057
# Epoch 60/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0672 - loss: 2.6154e-04 - mae: 0.0043 - val_accuracy: 0.0774 - val_loss: 2.4684e-04 - val_mae: 0.0041
# Epoch 61/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0667 - loss: 2.5012e-04 - mae: 0.0036 - val_accuracy: 0.0774 - val_loss: 2.1306e-04 - val_mae: 0.0030
# Epoch 62/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0700 - loss: 2.3950e-04 - mae: 0.0035 - val_accuracy: 0.0774 - val_loss: 2.2029e-04 - val_mae: 0.0037
# Epoch 63/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0651 - loss: 2.4151e-04 - mae: 0.0032 - val_accuracy: 0.0774 - val_loss: 2.0769e-04 - val_mae: 0.0034
# Epoch 64/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0687 - loss: 1.9462e-04 - mae: 0.0036 - val_accuracy: 0.0774 - val_loss: 2.5129e-04 - val_mae: 0.0045
# Epoch 65/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0623 - loss: 2.4331e-04 - mae: 0.0039 - val_accuracy: 0.0772 - val_loss: 2.7477e-04 - val_mae: 0.0035
# Epoch 66/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0643 - loss: 2.6636e-04 - mae: 0.0037 - val_accuracy: 0.0774 - val_loss: 2.1406e-04 - val_mae: 0.0039
# Epoch 67/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0690 - loss: 2.6653e-04 - mae: 0.0041 - val_accuracy: 0.0774 - val_loss: 2.0932e-04 - val_mae: 0.0034
# Epoch 68/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0701 - loss: 2.1608e-04 - mae: 0.0033 - val_accuracy: 0.0774 - val_loss: 2.1411e-04 - val_mae: 0.0033
# Epoch 69/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0691 - loss: 2.1381e-04 - mae: 0.0033 - val_accuracy: 0.0774 - val_loss: 2.2149e-04 - val_mae: 0.0043
# Epoch 70/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0654 - loss: 2.7340e-04 - mae: 0.0040 - val_accuracy: 0.0774 - val_loss: 2.3036e-04 - val_mae: 0.0058
# Epoch 71/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0642 - loss: 2.6398e-04 - mae: 0.0046 - val_accuracy: 0.0774 - val_loss: 2.1215e-04 - val_mae: 0.0040
# Epoch 72/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0661 - loss: 2.4222e-04 - mae: 0.0043 - val_accuracy: 0.0774 - val_loss: 2.1602e-04 - val_mae: 0.0048
# Epoch 73/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0687 - loss: 2.1746e-04 - mae: 0.0038 - val_accuracy: 0.0774 - val_loss: 3.4431e-04 - val_mae: 0.0123
# Epoch 74/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0667 - loss: 2.7023e-04 - mae: 0.0074 - val_accuracy: 0.0774 - val_loss: 2.1321e-04 - val_mae: 0.0036
# Epoch 75/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0649 - loss: 2.7227e-04 - mae: 0.0049 - val_accuracy: 0.0774 - val_loss: 2.3287e-04 - val_mae: 0.0030
# Epoch 76/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0680 - loss: 2.4058e-04 - mae: 0.0034 - val_accuracy: 0.0774 - val_loss: 2.4874e-04 - val_mae: 0.0036
# Epoch 77/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0647 - loss: 2.5532e-04 - mae: 0.0033 - val_accuracy: 0.0774 - val_loss: 2.0920e-04 - val_mae: 0.0031
# Epoch 78/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0680 - loss: 2.3326e-04 - mae: 0.0034 - val_accuracy: 0.0774 - val_loss: 2.1830e-04 - val_mae: 0.0030
# Epoch 79/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0664 - loss: 2.5677e-04 - mae: 0.0035 - val_accuracy: 0.0774 - val_loss: 2.0944e-04 - val_mae: 0.0037
# Epoch 80/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0644 - loss: 2.2318e-04 - mae: 0.0036 - val_accuracy: 0.0774 - val_loss: 2.3170e-04 - val_mae: 0.0029
# Epoch 81/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0670 - loss: 2.8269e-04 - mae: 0.0042 - val_accuracy: 0.0774 - val_loss: 2.1478e-04 - val_mae: 0.0031
# Epoch 82/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0682 - loss: 3.0024e-04 - mae: 0.0036 - val_accuracy: 0.0774 - val_loss: 2.1765e-04 - val_mae: 0.0034
# Epoch 83/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0648 - loss: 2.7459e-04 - mae: 0.0037 - val_accuracy: 0.0774 - val_loss: 2.0808e-04 - val_mae: 0.0030
# Epoch 84/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0656 - loss: 2.9597e-04 - mae: 0.0043 - val_accuracy: 0.0774 - val_loss: 2.4453e-04 - val_mae: 0.0036
# Epoch 85/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0657 - loss: 2.9125e-04 - mae: 0.0047 - val_accuracy: 0.0774 - val_loss: 2.1014e-04 - val_mae: 0.0031
# Epoch 86/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0649 - loss: 2.8483e-04 - mae: 0.0045 - val_accuracy: 0.0774 - val_loss: 2.2687e-04 - val_mae: 0.0030
# Epoch 87/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0660 - loss: 2.1955e-04 - mae: 0.0036 - val_accuracy: 0.0774 - val_loss: 2.1072e-04 - val_mae: 0.0027
# Epoch 88/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0655 - loss: 1.9995e-04 - mae: 0.0035 - val_accuracy: 0.0774 - val_loss: 2.1253e-04 - val_mae: 0.0034
# Epoch 89/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0673 - loss: 2.2289e-04 - mae: 0.0033 - val_accuracy: 0.0774 - val_loss: 2.0522e-04 - val_mae: 0.0028
# Epoch 90/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0686 - loss: 2.5291e-04 - mae: 0.0032 - val_accuracy: 0.0772 - val_loss: 3.0034e-04 - val_mae: 0.0047
# Epoch 91/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0668 - loss: 3.0144e-04 - mae: 0.0045 - val_accuracy: 0.0774 - val_loss: 2.4127e-04 - val_mae: 0.0031
# Epoch 92/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0649 - loss: 2.7911e-04 - mae: 0.0040 - val_accuracy: 0.0774 - val_loss: 2.0890e-04 - val_mae: 0.0028
# Epoch 93/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0669 - loss: 2.3287e-04 - mae: 0.0034 - val_accuracy: 0.0774 - val_loss: 2.2388e-04 - val_mae: 0.0043
# Epoch 94/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0663 - loss: 2.5132e-04 - mae: 0.0046 - val_accuracy: 0.0774 - val_loss: 2.3425e-04 - val_mae: 0.0057
# Epoch 95/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0654 - loss: 3.0585e-04 - mae: 0.0049 - val_accuracy: 0.0774 - val_loss: 2.8253e-04 - val_mae: 0.0080
# Epoch 96/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0670 - loss: 2.7913e-04 - mae: 0.0064 - val_accuracy: 0.0774 - val_loss: 2.3064e-04 - val_mae: 0.0051
# Epoch 97/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0669 - loss: 2.2704e-04 - mae: 0.0043 - val_accuracy: 0.0774 - val_loss: 2.0759e-04 - val_mae: 0.0043
# Epoch 98/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0668 - loss: 2.8061e-04 - mae: 0.0036 - val_accuracy: 0.0774 - val_loss: 2.1210e-04 - val_mae: 0.0041
# Epoch 99/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0669 - loss: 2.2733e-04 - mae: 0.0035 - val_accuracy: 0.0774 - val_loss: 2.1694e-04 - val_mae: 0.0038
# Epoch 100/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0664 - loss: 2.4190e-04 - mae: 0.0037 - val_accuracy: 0.0774 - val_loss: 2.6330e-04 - val_mae: 0.0034
# Epoch 101/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0671 - loss: 2.7435e-04 - mae: 0.0038 - val_accuracy: 0.0774 - val_loss: 2.2057e-04 - val_mae: 0.0030
# Epoch 102/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0677 - loss: 2.5057e-04 - mae: 0.0038 - val_accuracy: 0.0774 - val_loss: 2.0684e-04 - val_mae: 0.0029
# Epoch 103/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0698 - loss: 2.6054e-04 - mae: 0.0035 - val_accuracy: 0.0774 - val_loss: 2.4717e-04 - val_mae: 0.0073
# Epoch 104/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0666 - loss: 2.6783e-04 - mae: 0.0057 - val_accuracy: 0.0774 - val_loss: 2.2250e-04 - val_mae: 0.0062
# Epoch 105/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0670 - loss: 2.1326e-04 - mae: 0.0045 - val_accuracy: 0.0774 - val_loss: 2.2762e-04 - val_mae: 0.0045
# Epoch 106/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0652 - loss: 2.3019e-04 - mae: 0.0039 - val_accuracy: 0.0774 - val_loss: 2.4806e-04 - val_mae: 0.0072
# Epoch 107/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0712 - loss: 2.5058e-04 - mae: 0.0058 - val_accuracy: 0.0774 - val_loss: 2.4105e-04 - val_mae: 0.0072
# Epoch 108/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0666 - loss: 4.9453e-04 - mae: 0.0063 - val_accuracy: 0.0774 - val_loss: 3.2699e-04 - val_mae: 0.0095
# Epoch 109/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0650 - loss: 3.3844e-04 - mae: 0.0080 - val_accuracy: 0.0774 - val_loss: 3.7592e-04 - val_mae: 0.0119
# Epoch 110/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0671 - loss: 4.1695e-04 - mae: 0.0095 - val_accuracy: 0.0774 - val_loss: 3.2400e-04 - val_mae: 0.0036
# Epoch 111/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0669 - loss: 3.8766e-04 - mae: 0.0036 - val_accuracy: 0.0774 - val_loss: 2.9778e-04 - val_mae: 0.0031
# Epoch 112/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0653 - loss: 3.2554e-04 - mae: 0.0038 - val_accuracy: 0.0774 - val_loss: 2.6528e-04 - val_mae: 0.0039
# Epoch 113/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0698 - loss: 2.5876e-04 - mae: 0.0040 - val_accuracy: 0.0774 - val_loss: 2.5037e-04 - val_mae: 0.0036
# Epoch 114/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0653 - loss: 2.4587e-04 - mae: 0.0040 - val_accuracy: 0.0774 - val_loss: 2.4338e-04 - val_mae: 0.0045
# Epoch 115/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0665 - loss: 2.8216e-04 - mae: 0.0043 - val_accuracy: 0.0774 - val_loss: 2.4452e-04 - val_mae: 0.0048
# Epoch 116/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0687 - loss: 2.2608e-04 - mae: 0.0040 - val_accuracy: 0.0774 - val_loss: 2.5034e-04 - val_mae: 0.0043
# Epoch 117/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0677 - loss: 2.8635e-04 - mae: 0.0042 - val_accuracy: 0.0774 - val_loss: 2.5008e-04 - val_mae: 0.0055
# Epoch 118/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0644 - loss: 2.5524e-04 - mae: 0.0050 - val_accuracy: 0.0774 - val_loss: 2.5038e-04 - val_mae: 0.0047
# Epoch 119/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0682 - loss: 2.6360e-04 - mae: 0.0045 - val_accuracy: 0.0774 - val_loss: 2.4766e-04 - val_mae: 0.0036
# Epoch 120/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0662 - loss: 2.8071e-04 - mae: 0.0043 - val_accuracy: 0.0774 - val_loss: 2.4154e-04 - val_mae: 0.0036
# Epoch 121/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0689 - loss: 2.7319e-04 - mae: 0.0040 - val_accuracy: 0.0774 - val_loss: 2.3626e-04 - val_mae: 0.0059
# Epoch 122/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0658 - loss: 2.8104e-04 - mae: 0.0050 - val_accuracy: 0.0774 - val_loss: 2.2132e-04 - val_mae: 0.0037
# Epoch 123/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0680 - loss: 2.3560e-04 - mae: 0.0038 - val_accuracy: 0.0774 - val_loss: 2.2849e-04 - val_mae: 0.0051
# Epoch 124/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0654 - loss: 2.9450e-04 - mae: 0.0044 - val_accuracy: 0.0774 - val_loss: 2.1953e-04 - val_mae: 0.0043
# Epoch 125/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0684 - loss: 2.5072e-04 - mae: 0.0038 - val_accuracy: 0.0774 - val_loss: 2.6347e-04 - val_mae: 0.0074
# Epoch 126/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0679 - loss: 2.6454e-04 - mae: 0.0047 - val_accuracy: 0.0774 - val_loss: 0.0012 - val_mae: 0.0309
# Epoch 127/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0687 - loss: 5.7235e-04 - mae: 0.0147 - val_accuracy: 0.0774 - val_loss: 2.6807e-04 - val_mae: 0.0052
# Epoch 128/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0684 - loss: 3.6136e-04 - mae: 0.0043 - val_accuracy: 0.0774 - val_loss: 7.1989e-04 - val_mae: 0.0236
# Epoch 129/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0689 - loss: 4.8109e-04 - mae: 0.0133 - val_accuracy: 0.0774 - val_loss: 3.0878e-04 - val_mae: 0.0119
# Epoch 130/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0707 - loss: 3.1183e-04 - mae: 0.0067 - val_accuracy: 0.0774 - val_loss: 2.3693e-04 - val_mae: 0.0039
# Epoch 131/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0672 - loss: 2.6825e-04 - mae: 0.0036 - val_accuracy: 0.0774 - val_loss: 2.2836e-04 - val_mae: 0.0039
# Epoch 132/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0682 - loss: 2.2146e-04 - mae: 0.0037 - val_accuracy: 0.0774 - val_loss: 2.0549e-04 - val_mae: 0.0032
# Epoch 133/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0665 - loss: 1.9949e-04 - mae: 0.0032 - val_accuracy: 0.0774 - val_loss: 2.0920e-04 - val_mae: 0.0050
# Epoch 134/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0670 - loss: 2.5463e-04 - mae: 0.0041 - val_accuracy: 0.0774 - val_loss: 2.1819e-04 - val_mae: 0.0051
# Epoch 135/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0671 - loss: 2.6443e-04 - mae: 0.0043 - val_accuracy: 0.0774 - val_loss: 2.0438e-04 - val_mae: 0.0032
# Epoch 136/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0684 - loss: 2.6162e-04 - mae: 0.0036 - val_accuracy: 0.0774 - val_loss: 2.1696e-04 - val_mae: 0.0030
# Epoch 137/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0681 - loss: 2.7779e-04 - mae: 0.0034 - val_accuracy: 0.0774 - val_loss: 2.0607e-04 - val_mae: 0.0036
# Epoch 138/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0687 - loss: 2.1072e-04 - mae: 0.0035 - val_accuracy: 0.0774 - val_loss: 2.1994e-04 - val_mae: 0.0060
# Epoch 139/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0656 - loss: 2.4098e-04 - mae: 0.0044 - val_accuracy: 0.0774 - val_loss: 2.1546e-04 - val_mae: 0.0045
# Epoch 140/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0660 - loss: 2.7461e-04 - mae: 0.0043 - val_accuracy: 0.0774 - val_loss: 2.2370e-04 - val_mae: 0.0040
# Epoch 141/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0664 - loss: 2.4267e-04 - mae: 0.0035 - val_accuracy: 0.0774 - val_loss: 2.0491e-04 - val_mae: 0.0032
# Epoch 142/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0685 - loss: 2.8201e-04 - mae: 0.0036 - val_accuracy: 0.0774 - val_loss: 2.1390e-04 - val_mae: 0.0033
# Epoch 143/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0656 - loss: 2.2544e-04 - mae: 0.0033 - val_accuracy: 0.0774 - val_loss: 2.0770e-04 - val_mae: 0.0031
# Epoch 144/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0655 - loss: 2.5049e-04 - mae: 0.0033 - val_accuracy: 0.0774 - val_loss: 2.0827e-04 - val_mae: 0.0031
# Epoch 145/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0660 - loss: 2.7637e-04 - mae: 0.0032 - val_accuracy: 0.0774 - val_loss: 2.1374e-04 - val_mae: 0.0033
# Epoch 146/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0666 - loss: 2.5469e-04 - mae: 0.0037 - val_accuracy: 0.0774 - val_loss: 2.0851e-04 - val_mae: 0.0032
# Epoch 147/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0702 - loss: 2.4733e-04 - mae: 0.0034 - val_accuracy: 0.0774 - val_loss: 2.5079e-04 - val_mae: 0.0073
# Epoch 148/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0668 - loss: 2.6636e-04 - mae: 0.0050 - val_accuracy: 0.0774 - val_loss: 2.0799e-04 - val_mae: 0.0030
# Epoch 149/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0651 - loss: 2.5843e-04 - mae: 0.0035 - val_accuracy: 0.0774 - val_loss: 2.3242e-04 - val_mae: 0.0073
# Epoch 150/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0682 - loss: 2.3870e-04 - mae: 0.0048 - val_accuracy: 0.0774 - val_loss: 2.3833e-04 - val_mae: 0.0032
# Epoch 151/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0657 - loss: 2.2124e-04 - mae: 0.0033 - val_accuracy: 0.0774 - val_loss: 2.1081e-04 - val_mae: 0.0029
# Epoch 152/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0655 - loss: 2.0575e-04 - mae: 0.0032 - val_accuracy: 0.0774 - val_loss: 2.1113e-04 - val_mae: 0.0045
# Epoch 153/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0670 - loss: 2.3548e-04 - mae: 0.0042 - val_accuracy: 0.0774 - val_loss: 2.0863e-04 - val_mae: 0.0029
# Epoch 154/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0685 - loss: 2.2736e-04 - mae: 0.0030 - val_accuracy: 0.0774 - val_loss: 2.1431e-04 - val_mae: 0.0033
# Epoch 155/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0653 - loss: 2.1543e-04 - mae: 0.0036 - val_accuracy: 0.0774 - val_loss: 2.2500e-04 - val_mae: 0.0048
# Epoch 156/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0657 - loss: 2.9128e-04 - mae: 0.0039 - val_accuracy: 0.0774 - val_loss: 2.5244e-04 - val_mae: 0.0069
# Epoch 157/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0656 - loss: 2.5548e-04 - mae: 0.0049 - val_accuracy: 0.0774 - val_loss: 2.1062e-04 - val_mae: 0.0039
# Epoch 158/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0685 - loss: 2.3359e-04 - mae: 0.0034 - val_accuracy: 0.0774 - val_loss: 2.0923e-04 - val_mae: 0.0034
# Epoch 159/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0683 - loss: 2.4931e-04 - mae: 0.0036 - val_accuracy: 0.0774 - val_loss: 2.0271e-04 - val_mae: 0.0033
# Epoch 160/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0645 - loss: 2.7890e-04 - mae: 0.0035 - val_accuracy: 0.0774 - val_loss: 2.1966e-04 - val_mae: 0.0050
# Epoch 161/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0681 - loss: 2.2469e-04 - mae: 0.0042 - val_accuracy: 0.0774 - val_loss: 2.3154e-04 - val_mae: 0.0060
# Epoch 162/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0663 - loss: 5.0762e-04 - mae: 0.0060 - val_accuracy: 0.0772 - val_loss: 3.2568e-04 - val_mae: 0.0031
# Epoch 163/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0669 - loss: 3.6826e-04 - mae: 0.0045 - val_accuracy: 0.0774 - val_loss: 2.8151e-04 - val_mae: 0.0032
# Epoch 164/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0667 - loss: 3.3392e-04 - mae: 0.0040 - val_accuracy: 0.0772 - val_loss: 2.8753e-04 - val_mae: 0.0054
# Epoch 165/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0665 - loss: 2.8319e-04 - mae: 0.0040 - val_accuracy: 0.0774 - val_loss: 2.6517e-04 - val_mae: 0.0057
# Epoch 166/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0673 - loss: 3.1457e-04 - mae: 0.0046 - val_accuracy: 0.0774 - val_loss: 2.5792e-04 - val_mae: 0.0037
# Epoch 167/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0680 - loss: 2.7339e-04 - mae: 0.0041 - val_accuracy: 0.0774 - val_loss: 2.6759e-04 - val_mae: 0.0069
# Epoch 168/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0675 - loss: 2.8254e-04 - mae: 0.0049 - val_accuracy: 0.0774 - val_loss: 2.2771e-04 - val_mae: 0.0037
# Epoch 169/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0669 - loss: 2.4646e-04 - mae: 0.0038 - val_accuracy: 0.0774 - val_loss: 2.2776e-04 - val_mae: 0.0048
# Epoch 170/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0699 - loss: 2.3786e-04 - mae: 0.0041 - val_accuracy: 0.0774 - val_loss: 2.8343e-04 - val_mae: 0.0065
# Epoch 171/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0678 - loss: 3.2505e-04 - mae: 0.0051 - val_accuracy: 0.0774 - val_loss: 2.6296e-04 - val_mae: 0.0033
# Epoch 172/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0686 - loss: 2.9443e-04 - mae: 0.0037 - val_accuracy: 0.0774 - val_loss: 2.2848e-04 - val_mae: 0.0059
# Epoch 173/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0658 - loss: 2.3707e-04 - mae: 0.0040 - val_accuracy: 0.0774 - val_loss: 2.2199e-04 - val_mae: 0.0036
# Epoch 174/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0686 - loss: 2.3390e-04 - mae: 0.0040 - val_accuracy: 0.0774 - val_loss: 2.1698e-04 - val_mae: 0.0043
# Epoch 175/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0650 - loss: 2.7233e-04 - mae: 0.0047 - val_accuracy: 0.0774 - val_loss: 2.6435e-04 - val_mae: 0.0061
# Epoch 176/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0655 - loss: 2.8191e-04 - mae: 0.0050 - val_accuracy: 0.0774 - val_loss: 2.2061e-04 - val_mae: 0.0046
# Epoch 177/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0674 - loss: 2.2598e-04 - mae: 0.0040 - val_accuracy: 0.0774 - val_loss: 2.1411e-04 - val_mae: 0.0029
# Epoch 178/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0677 - loss: 2.4299e-04 - mae: 0.0038 - val_accuracy: 0.0774 - val_loss: 3.6375e-04 - val_mae: 0.0124
# Epoch 179/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0660 - loss: 2.9419e-04 - mae: 0.0074 - val_accuracy: 0.0774 - val_loss: 2.3174e-04 - val_mae: 0.0060
# Epoch 180/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0683 - loss: 2.6123e-04 - mae: 0.0050 - val_accuracy: 0.0774 - val_loss: 2.1130e-04 - val_mae: 0.0043
# Epoch 181/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0678 - loss: 2.5813e-04 - mae: 0.0039 - val_accuracy: 0.0774 - val_loss: 2.4600e-04 - val_mae: 0.0072
# Epoch 182/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0675 - loss: 3.6766e-04 - mae: 0.0051 - val_accuracy: 0.0774 - val_loss: 2.4583e-04 - val_mae: 0.0032
# Epoch 183/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0695 - loss: 2.6023e-04 - mae: 0.0038 - val_accuracy: 0.0774 - val_loss: 2.1585e-04 - val_mae: 0.0033
# Epoch 184/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0662 - loss: 2.2286e-04 - mae: 0.0036 - val_accuracy: 0.0774 - val_loss: 2.1253e-04 - val_mae: 0.0032
# Epoch 185/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0678 - loss: 2.4336e-04 - mae: 0.0037 - val_accuracy: 0.0774 - val_loss: 2.2351e-04 - val_mae: 0.0039
# Epoch 186/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0687 - loss: 2.0161e-04 - mae: 0.0035 - val_accuracy: 0.0774 - val_loss: 2.1515e-04 - val_mae: 0.0034
# Epoch 187/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0662 - loss: 2.3890e-04 - mae: 0.0044 - val_accuracy: 0.0774 - val_loss: 2.2034e-04 - val_mae: 0.0029
# Epoch 188/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0671 - loss: 2.1158e-04 - mae: 0.0033 - val_accuracy: 0.0774 - val_loss: 2.3070e-04 - val_mae: 0.0063
# Epoch 189/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0651 - loss: 2.4861e-04 - mae: 0.0041 - val_accuracy: 0.0774 - val_loss: 2.1154e-04 - val_mae: 0.0031
# Epoch 190/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0676 - loss: 2.3734e-04 - mae: 0.0033 - val_accuracy: 0.0774 - val_loss: 2.0587e-04 - val_mae: 0.0032
# Epoch 191/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0678 - loss: 2.0669e-04 - mae: 0.0036 - val_accuracy: 0.0774 - val_loss: 2.3380e-04 - val_mae: 0.0043
# Epoch 192/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0655 - loss: 2.8123e-04 - mae: 0.0036 - val_accuracy: 0.0774 - val_loss: 2.0688e-04 - val_mae: 0.0027
# Epoch 193/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0662 - loss: 2.7356e-04 - mae: 0.0036 - val_accuracy: 0.0774 - val_loss: 2.1429e-04 - val_mae: 0.0042
# Epoch 194/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0660 - loss: 2.3308e-04 - mae: 0.0039 - val_accuracy: 0.0774 - val_loss: 2.1074e-04 - val_mae: 0.0030
# Epoch 195/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0688 - loss: 2.1764e-04 - mae: 0.0033 - val_accuracy: 0.0774 - val_loss: 5.0999e-04 - val_mae: 0.0172
# Epoch 196/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0655 - loss: 4.5894e-04 - mae: 0.0121 - val_accuracy: 0.0774 - val_loss: 2.5262e-04 - val_mae: 0.0041
# Epoch 197/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0702 - loss: 2.7951e-04 - mae: 0.0046 - val_accuracy: 0.0774 - val_loss: 2.1350e-04 - val_mae: 0.0031
# Epoch 198/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0657 - loss: 2.7139e-04 - mae: 0.0036 - val_accuracy: 0.0774 - val_loss: 2.1090e-04 - val_mae: 0.0042
# Epoch 199/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0684 - loss: 2.2094e-04 - mae: 0.0037 - val_accuracy: 0.0774 - val_loss: 2.3880e-04 - val_mae: 0.0057
# Epoch 200/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0664 - loss: 2.9378e-04 - mae: 0.0047 - val_accuracy: 0.0774 - val_loss: 2.2270e-04 - val_mae: 0.0035
# Epoch 201/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0654 - loss: 2.2984e-04 - mae: 0.0038 - val_accuracy: 0.0774 - val_loss: 2.6378e-04 - val_mae: 0.0094
# Epoch 202/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0666 - loss: 2.7284e-04 - mae: 0.0063 - val_accuracy: 0.0774 - val_loss: 2.2805e-04 - val_mae: 0.0032
# Epoch 203/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0661 - loss: 2.5813e-04 - mae: 0.0040 - val_accuracy: 0.0774 - val_loss: 2.1437e-04 - val_mae: 0.0037
# Epoch 204/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0661 - loss: 2.2684e-04 - mae: 0.0046 - val_accuracy: 0.0774 - val_loss: 2.1165e-04 - val_mae: 0.0040
# Epoch 205/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0668 - loss: 2.6553e-04 - mae: 0.0039 - val_accuracy: 0.0774 - val_loss: 2.1576e-04 - val_mae: 0.0031
# Epoch 206/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0652 - loss: 2.9202e-04 - mae: 0.0039 - val_accuracy: 0.0774 - val_loss: 2.2304e-04 - val_mae: 0.0035
# Epoch 207/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0692 - loss: 2.5040e-04 - mae: 0.0035 - val_accuracy: 0.0774 - val_loss: 2.2207e-04 - val_mae: 0.0042
# Epoch 208/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0694 - loss: 2.3031e-04 - mae: 0.0045 - val_accuracy: 0.0774 - val_loss: 2.4269e-04 - val_mae: 0.0036
# Epoch 209/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0671 - loss: 2.7426e-04 - mae: 0.0040 - val_accuracy: 0.0774 - val_loss: 2.3064e-04 - val_mae: 0.0044
# Epoch 210/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0648 - loss: 2.8056e-04 - mae: 0.0041 - val_accuracy: 0.0774 - val_loss: 2.2018e-04 - val_mae: 0.0048
# Epoch 211/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0676 - loss: 2.5057e-04 - mae: 0.0036 - val_accuracy: 0.0774 - val_loss: 2.1246e-04 - val_mae: 0.0036
# Epoch 212/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0662 - loss: 2.2287e-04 - mae: 0.0040 - val_accuracy: 0.0774 - val_loss: 2.2421e-04 - val_mae: 0.0044
# Epoch 213/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0677 - loss: 2.3266e-04 - mae: 0.0040 - val_accuracy: 0.0774 - val_loss: 2.7216e-04 - val_mae: 0.0053
# Epoch 214/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0680 - loss: 2.2151e-04 - mae: 0.0040 - val_accuracy: 0.0774 - val_loss: 2.1640e-04 - val_mae: 0.0031
# Epoch 215/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0658 - loss: 1.9779e-04 - mae: 0.0032 - val_accuracy: 0.0774 - val_loss: 2.1298e-04 - val_mae: 0.0036
# Epoch 216/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0679 - loss: 2.4767e-04 - mae: 0.0037 - val_accuracy: 0.0774 - val_loss: 2.1245e-04 - val_mae: 0.0030
# Epoch 217/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0684 - loss: 2.3128e-04 - mae: 0.0037 - val_accuracy: 0.0774 - val_loss: 2.1219e-04 - val_mae: 0.0033
# Epoch 218/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0661 - loss: 3.0830e-04 - mae: 0.0037 - val_accuracy: 0.0774 - val_loss: 2.0785e-04 - val_mae: 0.0032
# Epoch 219/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0706 - loss: 2.3413e-04 - mae: 0.0036 - val_accuracy: 0.0774 - val_loss: 2.0743e-04 - val_mae: 0.0037
# Epoch 220/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0660 - loss: 2.7943e-04 - mae: 0.0037 - val_accuracy: 0.0774 - val_loss: 2.3282e-04 - val_mae: 0.0047
# Epoch 221/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0663 - loss: 2.3298e-04 - mae: 0.0036 - val_accuracy: 0.0774 - val_loss: 2.2173e-04 - val_mae: 0.0045
# Epoch 222/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0695 - loss: 2.3097e-04 - mae: 0.0039 - val_accuracy: 0.0774 - val_loss: 2.1939e-04 - val_mae: 0.0032
# Epoch 223/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0658 - loss: 2.3973e-04 - mae: 0.0037 - val_accuracy: 0.0774 - val_loss: 2.0891e-04 - val_mae: 0.0029
# Epoch 224/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0679 - loss: 1.9609e-04 - mae: 0.0040 - val_accuracy: 0.0774 - val_loss: 2.1275e-04 - val_mae: 0.0042
# Epoch 225/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0675 - loss: 2.6832e-04 - mae: 0.0041 - val_accuracy: 0.0774 - val_loss: 2.4617e-04 - val_mae: 0.0030
# Epoch 226/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0673 - loss: 2.5248e-04 - mae: 0.0034 - val_accuracy: 0.0774 - val_loss: 2.1130e-04 - val_mae: 0.0039
# Epoch 227/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0671 - loss: 2.2956e-04 - mae: 0.0033 - val_accuracy: 0.0774 - val_loss: 2.1535e-04 - val_mae: 0.0035
# Epoch 228/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0690 - loss: 2.1249e-04 - mae: 0.0035 - val_accuracy: 0.0774 - val_loss: 2.1248e-04 - val_mae: 0.0051
# Epoch 229/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0654 - loss: 2.0843e-04 - mae: 0.0039 - val_accuracy: 0.0774 - val_loss: 2.2012e-04 - val_mae: 0.0034
# Epoch 230/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0679 - loss: 2.3643e-04 - mae: 0.0039 - val_accuracy: 0.0774 - val_loss: 2.2146e-04 - val_mae: 0.0030
# Epoch 231/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0698 - loss: 2.3230e-04 - mae: 0.0034 - val_accuracy: 0.0774 - val_loss: 2.3608e-04 - val_mae: 0.0072
# Epoch 232/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0640 - loss: 2.5046e-04 - mae: 0.0048 - val_accuracy: 0.0774 - val_loss: 3.7952e-04 - val_mae: 0.0131
# Epoch 233/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0666 - loss: 3.9554e-04 - mae: 0.0084 - val_accuracy: 0.0774 - val_loss: 2.6328e-04 - val_mae: 0.0056
# Epoch 234/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0634 - loss: 3.0298e-04 - mae: 0.0044 - val_accuracy: 0.0774 - val_loss: 2.4191e-04 - val_mae: 0.0033
# Epoch 235/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0703 - loss: 2.7393e-04 - mae: 0.0039 - val_accuracy: 0.0774 - val_loss: 2.3812e-04 - val_mae: 0.0035
# Epoch 236/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0654 - loss: 2.5437e-04 - mae: 0.0039 - val_accuracy: 0.0774 - val_loss: 2.4587e-04 - val_mae: 0.0055
# Epoch 237/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0677 - loss: 2.9283e-04 - mae: 0.0053 - val_accuracy: 0.0774 - val_loss: 2.3242e-04 - val_mae: 0.0039
# Epoch 238/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0681 - loss: 2.3323e-04 - mae: 0.0035 - val_accuracy: 0.0774 - val_loss: 2.3372e-04 - val_mae: 0.0040
# Epoch 239/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0668 - loss: 2.4463e-04 - mae: 0.0040 - val_accuracy: 0.0774 - val_loss: 2.4194e-04 - val_mae: 0.0047
# Epoch 240/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0647 - loss: 2.1242e-04 - mae: 0.0036 - val_accuracy: 0.0774 - val_loss: 2.5137e-04 - val_mae: 0.0068
# Epoch 241/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0677 - loss: 2.3590e-04 - mae: 0.0050 - val_accuracy: 0.0774 - val_loss: 2.2021e-04 - val_mae: 0.0050
# Epoch 242/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0691 - loss: 2.6914e-04 - mae: 0.0040 - val_accuracy: 0.0774 - val_loss: 2.1422e-04 - val_mae: 0.0040
# Epoch 243/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0659 - loss: 2.3188e-04 - mae: 0.0036 - val_accuracy: 0.0774 - val_loss: 2.2301e-04 - val_mae: 0.0045
# Epoch 244/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0673 - loss: 2.4929e-04 - mae: 0.0043 - val_accuracy: 0.0774 - val_loss: 2.2108e-04 - val_mae: 0.0053
# Epoch 245/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0681 - loss: 2.5608e-04 - mae: 0.0043 - val_accuracy: 0.0774 - val_loss: 2.1318e-04 - val_mae: 0.0031
# Epoch 246/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0639 - loss: 1.9788e-04 - mae: 0.0035 - val_accuracy: 0.0774 - val_loss: 2.1773e-04 - val_mae: 0.0031
# Epoch 247/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0696 - loss: 2.1186e-04 - mae: 0.0033 - val_accuracy: 0.0774 - val_loss: 2.1406e-04 - val_mae: 0.0047
# Epoch 248/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0645 - loss: 2.2864e-04 - mae: 0.0039 - val_accuracy: 0.0774 - val_loss: 2.1265e-04 - val_mae: 0.0034
# Epoch 249/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0667 - loss: 2.5335e-04 - mae: 0.0036 - val_accuracy: 0.0774 - val_loss: 2.1717e-04 - val_mae: 0.0029
# Epoch 250/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0659 - loss: 2.9581e-04 - mae: 0.0040 - val_accuracy: 0.0774 - val_loss: 2.1297e-04 - val_mae: 0.0033
# Epoch 251/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0685 - loss: 2.1411e-04 - mae: 0.0035 - val_accuracy: 0.0774 - val_loss: 2.5425e-04 - val_mae: 0.0045
# Epoch 252/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0677 - loss: 3.1008e-04 - mae: 0.0048 - val_accuracy: 0.0774 - val_loss: 2.3002e-04 - val_mae: 0.0031
# Epoch 253/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0708 - loss: 2.8137e-04 - mae: 0.0048 - val_accuracy: 0.0774 - val_loss: 2.1411e-04 - val_mae: 0.0030
# Epoch 254/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0672 - loss: 2.7495e-04 - mae: 0.0037 - val_accuracy: 0.0774 - val_loss: 2.3028e-04 - val_mae: 0.0056
# Epoch 255/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0692 - loss: 2.2647e-04 - mae: 0.0045 - val_accuracy: 0.0774 - val_loss: 2.1600e-04 - val_mae: 0.0031
# Epoch 256/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0671 - loss: 2.4352e-04 - mae: 0.0034 - val_accuracy: 0.0774 - val_loss: 2.1904e-04 - val_mae: 0.0029
# Epoch 257/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0652 - loss: 2.6425e-04 - mae: 0.0036 - val_accuracy: 0.0774 - val_loss: 2.1194e-04 - val_mae: 0.0029
# Epoch 258/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0682 - loss: 2.1955e-04 - mae: 0.0031 - val_accuracy: 0.0774 - val_loss: 2.1104e-04 - val_mae: 0.0029
# Epoch 259/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0678 - loss: 2.4752e-04 - mae: 0.0037 - val_accuracy: 0.0774 - val_loss: 2.1462e-04 - val_mae: 0.0046
# Epoch 260/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0661 - loss: 2.0994e-04 - mae: 0.0038 - val_accuracy: 0.0774 - val_loss: 2.1520e-04 - val_mae: 0.0031
# Epoch 261/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0645 - loss: 2.5742e-04 - mae: 0.0035 - val_accuracy: 0.0774 - val_loss: 2.1007e-04 - val_mae: 0.0034
# Epoch 262/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0658 - loss: 2.2472e-04 - mae: 0.0040 - val_accuracy: 0.0774 - val_loss: 2.1496e-04 - val_mae: 0.0032
# Epoch 263/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0684 - loss: 2.5070e-04 - mae: 0.0034 - val_accuracy: 0.0774 - val_loss: 2.1155e-04 - val_mae: 0.0035
# Epoch 264/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0641 - loss: 2.4104e-04 - mae: 0.0050 - val_accuracy: 0.0774 - val_loss: 2.2330e-04 - val_mae: 0.0030
# Epoch 265/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0703 - loss: 2.5562e-04 - mae: 0.0034 - val_accuracy: 0.0774 - val_loss: 2.1799e-04 - val_mae: 0.0031
# Epoch 266/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0653 - loss: 2.3169e-04 - mae: 0.0037 - val_accuracy: 0.0774 - val_loss: 2.4607e-04 - val_mae: 0.0074
# Epoch 267/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0696 - loss: 2.4003e-04 - mae: 0.0059 - val_accuracy: 0.0774 - val_loss: 2.2358e-04 - val_mae: 0.0052
# Epoch 268/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0671 - loss: 1.9441e-04 - mae: 0.0038 - val_accuracy: 0.0774 - val_loss: 2.2302e-04 - val_mae: 0.0034
# Epoch 269/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0669 - loss: 2.6312e-04 - mae: 0.0039 - val_accuracy: 0.0774 - val_loss: 2.2887e-04 - val_mae: 0.0030
# Epoch 270/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0694 - loss: 2.1389e-04 - mae: 0.0037 - val_accuracy: 0.0774 - val_loss: 2.2158e-04 - val_mae: 0.0037
# Epoch 271/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0703 - loss: 2.3823e-04 - mae: 0.0037 - val_accuracy: 0.0774 - val_loss: 2.1209e-04 - val_mae: 0.0038
# Epoch 272/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0648 - loss: 2.3657e-04 - mae: 0.0040 - val_accuracy: 0.0774 - val_loss: 2.1274e-04 - val_mae: 0.0040
# Epoch 273/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0653 - loss: 2.2522e-04 - mae: 0.0040 - val_accuracy: 0.0774 - val_loss: 2.1268e-04 - val_mae: 0.0033
# Epoch 274/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0672 - loss: 2.1026e-04 - mae: 0.0033 - val_accuracy: 0.0774 - val_loss: 2.2491e-04 - val_mae: 0.0055
# Epoch 275/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0662 - loss: 2.1964e-04 - mae: 0.0039 - val_accuracy: 0.0774 - val_loss: 2.1869e-04 - val_mae: 0.0035
# Epoch 276/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0665 - loss: 2.3517e-04 - mae: 0.0040 - val_accuracy: 0.0774 - val_loss: 2.1236e-04 - val_mae: 0.0038
# Epoch 277/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0681 - loss: 2.5593e-04 - mae: 0.0033 - val_accuracy: 0.0774 - val_loss: 5.3617e-04 - val_mae: 0.0181
# Epoch 278/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0660 - loss: 5.1228e-04 - mae: 0.0135 - val_accuracy: 0.0774 - val_loss: 2.4757e-04 - val_mae: 0.0031
# Epoch 279/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0671 - loss: 2.8382e-04 - mae: 0.0035 - val_accuracy: 0.0774 - val_loss: 2.1817e-04 - val_mae: 0.0030
# Epoch 280/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0663 - loss: 2.2785e-04 - mae: 0.0034 - val_accuracy: 0.0774 - val_loss: 2.1278e-04 - val_mae: 0.0031
# Epoch 281/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0668 - loss: 2.5206e-04 - mae: 0.0035 - val_accuracy: 0.0774 - val_loss: 2.1220e-04 - val_mae: 0.0030
# Epoch 282/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0681 - loss: 2.4728e-04 - mae: 0.0034 - val_accuracy: 0.0774 - val_loss: 2.7124e-04 - val_mae: 0.0037
# Epoch 283/500
# ...
# Epoch 407/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0658 - loss: 2.1353e-04 - mae: 0.0036 - val_accuracy: 0.0774 - val_loss: 2.2727e-04 - val_mae: 0.0044
# Epoch 408/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0667 - loss: 2.1126e-04 - mae: 0.0037 - val_accuracy: 0.0774 - val_loss: 2.3616e-04 - val_mae: 0.0052
# Epoch 409/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0671 - loss: 2.5477e-04 - mae: 0.0040 - val_accuracy: 0.0774 - val_loss: 2.2674e-04 - val_mae: 0.0034
# Epoch 410/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0677 - loss: 2.2901e-04 - mae: 0.0036 - val_accuracy: 0.0774 - val_loss: 2.3325e-04 - val_mae: 0.0053
# Epoch 411/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0642 - loss: 2.4351e-04 - mae: 0.0040 - val_accuracy: 0.0774 - val_loss: 2.2753e-04 - val_mae: 0.0046
# Epoch 412/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0667 - loss: 2.0786e-04 - mae: 0.0038 - val_accuracy: 0.0774 - val_loss: 2.2384e-04 - val_mae: 0.0031
# Epoch 413/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0671 - loss: 1.9315e-04 - mae: 0.0031 - val_accuracy: 0.0774 - val_loss: 2.1536e-04 - val_mae: 0.0032
# Epoch 414/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0671 - loss: 2.8352e-04 - mae: 0.0038 - val_accuracy: 0.0774 - val_loss: 2.1924e-04 - val_mae: 0.0035
# Epoch 415/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0679 - loss: 2.2305e-04 - mae: 0.0033 - val_accuracy: 0.0774 - val_loss: 2.2785e-04 - val_mae: 0.0029
# Epoch 416/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0685 - loss: 2.2816e-04 - mae: 0.0034 - val_accuracy: 0.0774 - val_loss: 2.4098e-04 - val_mae: 0.0046
# Epoch 417/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0654 - loss: 3.1912e-04 - mae: 0.0042 - val_accuracy: 0.0772 - val_loss: 2.9297e-04 - val_mae: 0.0031
# Epoch 418/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0666 - loss: 2.5332e-04 - mae: 0.0038 - val_accuracy: 0.0774 - val_loss: 2.4872e-04 - val_mae: 0.0036
# Epoch 419/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0680 - loss: 2.5664e-04 - mae: 0.0043 - val_accuracy: 0.0774 - val_loss: 2.4601e-04 - val_mae: 0.0046
# Epoch 420/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0681 - loss: 2.4584e-04 - mae: 0.0046 - val_accuracy: 0.0774 - val_loss: 2.1021e-04 - val_mae: 0.0031
# Epoch 421/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0658 - loss: 2.0427e-04 - mae: 0.0034 - val_accuracy: 0.0774 - val_loss: 2.1599e-04 - val_mae: 0.0047
# Epoch 422/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0684 - loss: 2.4926e-04 - mae: 0.0042 - val_accuracy: 0.0774 - val_loss: 2.2607e-04 - val_mae: 0.0040
# Epoch 423/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0684 - loss: 2.5523e-04 - mae: 0.0036 - val_accuracy: 0.0774 - val_loss: 2.2540e-04 - val_mae: 0.0030
# Epoch 424/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0671 - loss: 2.1217e-04 - mae: 0.0038 - val_accuracy: 0.0774 - val_loss: 2.1967e-04 - val_mae: 0.0046
# Epoch 425/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0671 - loss: 2.4415e-04 - mae: 0.0038 - val_accuracy: 0.0774 - val_loss: 2.2885e-04 - val_mae: 0.0054
# Epoch 426/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0664 - loss: 2.1600e-04 - mae: 0.0041 - val_accuracy: 0.0774 - val_loss: 2.2446e-04 - val_mae: 0.0041
# Epoch 427/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0674 - loss: 2.1840e-04 - mae: 0.0038 - val_accuracy: 0.0774 - val_loss: 2.2057e-04 - val_mae: 0.0030
# Epoch 428/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0674 - loss: 2.1649e-04 - mae: 0.0033 - val_accuracy: 0.0774 - val_loss: 2.3879e-04 - val_mae: 0.0067
# Epoch 429/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0661 - loss: 2.5892e-04 - mae: 0.0045 - val_accuracy: 0.0774 - val_loss: 2.2703e-04 - val_mae: 0.0040
# Epoch 430/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0656 - loss: 2.2209e-04 - mae: 0.0038 - val_accuracy: 0.0774 - val_loss: 2.3170e-04 - val_mae: 0.0033
# Epoch 431/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0652 - loss: 1.9763e-04 - mae: 0.0031 - val_accuracy: 0.0774 - val_loss: 2.5658e-04 - val_mae: 0.0069
# Epoch 432/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0684 - loss: 2.3140e-04 - mae: 0.0052 - val_accuracy: 0.0774 - val_loss: 2.3240e-04 - val_mae: 0.0040
# Epoch 433/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0703 - loss: 2.4677e-04 - mae: 0.0043 - val_accuracy: 0.0774 - val_loss: 2.2324e-04 - val_mae: 0.0034
# Epoch 434/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0660 - loss: 2.3749e-04 - mae: 0.0033 - val_accuracy: 0.0774 - val_loss: 2.1938e-04 - val_mae: 0.0029
# Epoch 435/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0676 - loss: 2.1230e-04 - mae: 0.0034 - val_accuracy: 0.0774 - val_loss: 2.2905e-04 - val_mae: 0.0030
# Epoch 436/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0694 - loss: 2.3507e-04 - mae: 0.0036 - val_accuracy: 0.0774 - val_loss: 2.2621e-04 - val_mae: 0.0044
# Epoch 437/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0678 - loss: 2.1967e-04 - mae: 0.0039 - val_accuracy: 0.0774 - val_loss: 2.5283e-04 - val_mae: 0.0071
# Epoch 438/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0661 - loss: 2.8342e-04 - mae: 0.0050 - val_accuracy: 0.0774 - val_loss: 2.3205e-04 - val_mae: 0.0060
# Epoch 439/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0676 - loss: 2.5771e-04 - mae: 0.0045 - val_accuracy: 0.0774 - val_loss: 2.1468e-04 - val_mae: 0.0031
# Epoch 440/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0669 - loss: 2.6802e-04 - mae: 0.0044 - val_accuracy: 0.0774 - val_loss: 2.1536e-04 - val_mae: 0.0035
# Epoch 441/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0672 - loss: 2.6221e-04 - mae: 0.0036 - val_accuracy: 0.0772 - val_loss: 2.7717e-04 - val_mae: 0.0032
# Epoch 442/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0649 - loss: 2.6238e-04 - mae: 0.0039 - val_accuracy: 0.0774 - val_loss: 2.2096e-04 - val_mae: 0.0045
# Epoch 443/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0652 - loss: 2.4175e-04 - mae: 0.0045 - val_accuracy: 0.0774 - val_loss: 2.4118e-04 - val_mae: 0.0051
# Epoch 444/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0679 - loss: 2.4520e-04 - mae: 0.0042 - val_accuracy: 0.0774 - val_loss: 2.2181e-04 - val_mae: 0.0041
# Epoch 445/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0689 - loss: 2.6796e-04 - mae: 0.0038 - val_accuracy: 0.0774 - val_loss: 2.3210e-04 - val_mae: 0.0035
# Epoch 446/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0652 - loss: 2.4504e-04 - mae: 0.0035 - val_accuracy: 0.0774 - val_loss: 2.2968e-04 - val_mae: 0.0030
# Epoch 447/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0691 - loss: 1.8976e-04 - mae: 0.0032 - val_accuracy: 0.0774 - val_loss: 2.1576e-04 - val_mae: 0.0036
# Epoch 448/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0645 - loss: 2.1018e-04 - mae: 0.0042 - val_accuracy: 0.0774 - val_loss: 2.2073e-04 - val_mae: 0.0035
# Epoch 449/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0679 - loss: 2.0327e-04 - mae: 0.0035 - val_accuracy: 0.0774 - val_loss: 2.4030e-04 - val_mae: 0.0052
# Epoch 450/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0673 - loss: 2.4080e-04 - mae: 0.0050 - val_accuracy: 0.0774 - val_loss: 2.3326e-04 - val_mae: 0.0032
# Epoch 451/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0671 - loss: 2.0551e-04 - mae: 0.0039 - val_accuracy: 0.0774 - val_loss: 2.8005e-04 - val_mae: 0.0079
# Epoch 452/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0677 - loss: 3.1511e-04 - mae: 0.0066 - val_accuracy: 0.0774 - val_loss: 4.6616e-04 - val_mae: 0.0167
# Epoch 453/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0646 - loss: 3.6310e-04 - mae: 0.0115 - val_accuracy: 0.0774 - val_loss: 2.3320e-04 - val_mae: 0.0045
# Epoch 454/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0668 - loss: 2.0098e-04 - mae: 0.0037 - val_accuracy: 0.0774 - val_loss: 2.4118e-04 - val_mae: 0.0057
# Epoch 455/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0682 - loss: 2.6248e-04 - mae: 0.0054 - val_accuracy: 0.0774 - val_loss: 2.2716e-04 - val_mae: 0.0035
# Epoch 456/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0666 - loss: 1.9942e-04 - mae: 0.0035 - val_accuracy: 0.0774 - val_loss: 2.2308e-04 - val_mae: 0.0034
# Epoch 457/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0696 - loss: 2.2798e-04 - mae: 0.0035 - val_accuracy: 0.0774 - val_loss: 2.2222e-04 - val_mae: 0.0029
# Epoch 458/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0659 - loss: 2.7752e-04 - mae: 0.0040 - val_accuracy: 0.0774 - val_loss: 2.3033e-04 - val_mae: 0.0032
# Epoch 459/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0653 - loss: 2.4263e-04 - mae: 0.0032 - val_accuracy: 0.0774 - val_loss: 2.1497e-04 - val_mae: 0.0038
# Epoch 460/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0676 - loss: 2.3204e-04 - mae: 0.0032 - val_accuracy: 0.0774 - val_loss: 2.1724e-04 - val_mae: 0.0046
# Epoch 461/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0678 - loss: 2.1772e-04 - mae: 0.0039 - val_accuracy: 0.0774 - val_loss: 2.5159e-04 - val_mae: 0.0078
# Epoch 462/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0673 - loss: 2.4392e-04 - mae: 0.0057 - val_accuracy: 0.0774 - val_loss: 2.2975e-04 - val_mae: 0.0046
# Epoch 463/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0675 - loss: 2.1631e-04 - mae: 0.0039 - val_accuracy: 0.0774 - val_loss: 2.1441e-04 - val_mae: 0.0036
# Epoch 464/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0640 - loss: 2.5854e-04 - mae: 0.0038 - val_accuracy: 0.0774 - val_loss: 2.1875e-04 - val_mae: 0.0039
# Epoch 465/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0668 - loss: 2.5164e-04 - mae: 0.0043 - val_accuracy: 0.0774 - val_loss: 2.3354e-04 - val_mae: 0.0034
# Epoch 466/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0653 - loss: 2.5171e-04 - mae: 0.0038 - val_accuracy: 0.0774 - val_loss: 2.1449e-04 - val_mae: 0.0032
# Epoch 467/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0674 - loss: 2.3179e-04 - mae: 0.0031 - val_accuracy: 0.0774 - val_loss: 2.2217e-04 - val_mae: 0.0030
# Epoch 468/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0689 - loss: 2.4478e-04 - mae: 0.0035 - val_accuracy: 0.0774 - val_loss: 2.2258e-04 - val_mae: 0.0045
# Epoch 469/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0666 - loss: 2.3202e-04 - mae: 0.0039 - val_accuracy: 0.0774 - val_loss: 2.1835e-04 - val_mae: 0.0041
# Epoch 470/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0676 - loss: 2.7246e-04 - mae: 0.0035 - val_accuracy: 0.0774 - val_loss: 2.1984e-04 - val_mae: 0.0036
# Epoch 471/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0667 - loss: 2.4781e-04 - mae: 0.0034 - val_accuracy: 0.0774 - val_loss: 2.1499e-04 - val_mae: 0.0029
# Epoch 472/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0655 - loss: 2.1483e-04 - mae: 0.0031 - val_accuracy: 0.0774 - val_loss: 2.1874e-04 - val_mae: 0.0032
# Epoch 473/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0685 - loss: 2.1297e-04 - mae: 0.0034 - val_accuracy: 0.0774 - val_loss: 2.1674e-04 - val_mae: 0.0029
# Epoch 474/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0665 - loss: 2.1594e-04 - mae: 0.0032 - val_accuracy: 0.0774 - val_loss: 2.2464e-04 - val_mae: 0.0051
# Epoch 475/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0650 - loss: 2.4513e-04 - mae: 0.0042 - val_accuracy: 0.0774 - val_loss: 2.6163e-04 - val_mae: 0.0080
# Epoch 476/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0677 - loss: 2.4758e-04 - mae: 0.0066 - val_accuracy: 0.0774 - val_loss: 2.1860e-04 - val_mae: 0.0034
# Epoch 477/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0676 - loss: 2.6569e-04 - mae: 0.0039 - val_accuracy: 0.0774 - val_loss: 2.2463e-04 - val_mae: 0.0043
# Epoch 478/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0686 - loss: 2.4059e-04 - mae: 0.0038 - val_accuracy: 0.0774 - val_loss: 2.2362e-04 - val_mae: 0.0041
# Epoch 479/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0689 - loss: 2.5419e-04 - mae: 0.0037 - val_accuracy: 0.0774 - val_loss: 2.1931e-04 - val_mae: 0.0031
# Epoch 480/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0682 - loss: 2.4593e-04 - mae: 0.0042 - val_accuracy: 0.0774 - val_loss: 3.8293e-04 - val_mae: 0.0134
# Epoch 481/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0679 - loss: 2.9832e-04 - mae: 0.0082 - val_accuracy: 0.0774 - val_loss: 2.3277e-04 - val_mae: 0.0031
# Epoch 482/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0680 - loss: 2.3674e-04 - mae: 0.0035 - val_accuracy: 0.0774 - val_loss: 2.3004e-04 - val_mae: 0.0032
# Epoch 483/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0637 - loss: 2.2348e-04 - mae: 0.0033 - val_accuracy: 0.0774 - val_loss: 2.2461e-04 - val_mae: 0.0031
# Epoch 484/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0684 - loss: 2.0838e-04 - mae: 0.0032 - val_accuracy: 0.0774 - val_loss: 2.2275e-04 - val_mae: 0.0040
# Epoch 485/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0665 - loss: 2.3445e-04 - mae: 0.0041 - val_accuracy: 0.0774 - val_loss: 2.2213e-04 - val_mae: 0.0050
# Epoch 486/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0696 - loss: 2.1184e-04 - mae: 0.0041 - val_accuracy: 0.0774 - val_loss: 2.2311e-04 - val_mae: 0.0043
# Epoch 487/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0648 - loss: 2.1838e-04 - mae: 0.0036 - val_accuracy: 0.0774 - val_loss: 2.2030e-04 - val_mae: 0.0029
# Epoch 488/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0668 - loss: 2.0076e-04 - mae: 0.0032 - val_accuracy: 0.0774 - val_loss: 2.2110e-04 - val_mae: 0.0042
# Epoch 489/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0662 - loss: 2.2332e-04 - mae: 0.0036 - val_accuracy: 0.0774 - val_loss: 2.2076e-04 - val_mae: 0.0036
# Epoch 490/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0657 - loss: 2.3717e-04 - mae: 0.0036 - val_accuracy: 0.0774 - val_loss: 2.1925e-04 - val_mae: 0.0037
# Epoch 491/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0678 - loss: 1.7052e-04 - mae: 0.0030 - val_accuracy: 0.0774 - val_loss: 2.4292e-04 - val_mae: 0.0068
# Epoch 492/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0655 - loss: 2.3360e-04 - mae: 0.0049 - val_accuracy: 0.0774 - val_loss: 2.1803e-04 - val_mae: 0.0039
# Epoch 493/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0674 - loss: 2.1009e-04 - mae: 0.0036 - val_accuracy: 0.0774 - val_loss: 2.2653e-04 - val_mae: 0.0029
# Epoch 494/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0655 - loss: 2.1459e-04 - mae: 0.0033 - val_accuracy: 0.0774 - val_loss: 2.2879e-04 - val_mae: 0.0039
# Epoch 495/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0681 - loss: 2.6668e-04 - mae: 0.0035 - val_accuracy: 0.0774 - val_loss: 2.2943e-04 - val_mae: 0.0039
# Epoch 496/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0642 - loss: 2.0821e-04 - mae: 0.0034 - val_accuracy: 0.0774 - val_loss: 2.2140e-04 - val_mae: 0.0029
# Epoch 497/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0682 - loss: 2.7987e-04 - mae: 0.0040 - val_accuracy: 0.0774 - val_loss: 2.3050e-04 - val_mae: 0.0037
# Epoch 498/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0660 - loss: 2.3294e-04 - mae: 0.0035 - val_accuracy: 0.0774 - val_loss: 2.2599e-04 - val_mae: 0.0031
# Epoch 499/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0642 - loss: 2.2214e-04 - mae: 0.0037 - val_accuracy: 0.0774 - val_loss: 2.5561e-04 - val_mae: 0.0066
# Epoch 500/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0652 - loss: 2.3795e-04 - mae: 0.0051 - val_accuracy: 0.0774 - val_loss: 2.3531e-04 - val_mae: 0.0069

# %%
# Step 7: Evaluate
test_loss = model.evaluate(X_test, y_test)
print(f"Test MAPE: {test_loss}")

# Step 8: Predict
predictions = model.predict(X_test)
y_pred = scaler_y.inverse_transform(predictions)
# Out:
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0746 - loss: 3.0166e-04 - mae: 0.0054
# Test MAPE: [0.00023518690431956202, 0.005146929528564215, 0.07740676403045654]
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

# Compute MSE
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error (MSE):", mse)

# print((max(y_train) - min(y_train))**2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss',color='r',alpha=0.7)
plt.xlabel('Epochs')
plt.title('Mean Squared Error')
plt.ylim(0, 0.001)
plt.legend()
plt.show()
# Out:
# Mean Squared Error (MSE): 50012916.38239883

# %%
# plt.plot(history.history['accuracy'],'b')
# plt.plot(history.history['val_accuracy'],'r')
# plt.title('Model accuracy')
# plt.ylabel('Accuracy')
# plt.xlabel('Epoch')
# plt.legend(['Train', 'Test'], loc='upper left')
# plt.show()

# Make predictions on the validation set
# y_pred = FNN.predict(X_val)
# print(y_pred.size)
# print(X_val.size)
# # Compare predictions with actual values
# plt.plot(y_pred, alpha=0.5)
# plt.title('Predictions vs Actual Values')
# plt.xlabel('Actual Values')
# plt.ylabel('Predicted Values')
# plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Step 1: Predict values
y_pred = model.predict(X_test)

# Step 2: Create the scatter plot
plt.figure(figsize=(6,6))
plt.scatter(y_test*max(y), y_pred*max(y), alpha=0.5, label="Predicted vs Actual")
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'r--', label='1:1 (y=x)', linewidth=2)

# Step 3: Add labels, title, and legend
plt.title("Streamflow Actual vs Predicted Values")
plt.xlabel("Actual Values [m3/s]")
plt.ylabel("Predicted Values [m3/s]")
plt.legend()
plt.grid(alpha=0.5)

# Step 4: Show the plot
plt.show()
# Out:
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step

# %%
# Plot y_test and y_pred as a time series
plt.figure(figsize=(12, 6))
plt.plot(np.arange(len(y_test)), y_test*max(y), label="Actual Values (y_test)", color="blue", alpha=0.7)
plt.plot(np.arange(len(y_pred)), y_pred*max(y), label="Predicted Values (y_pred)", color="red", alpha=0.7)

# error = y_test + 0.0033

# fig, (ax0, ax1) = plt.subplots(nrows=2, sharex=True)
# ax0.errorbar(x, y, yerr=error)
# 0.0033 
# Add titles and labels
plt.title("Time Series Comparison of Actual vs Predicted Values")
# plt.xlabel("Time Step")
plt.ylabel("Streamflow [m3/s]")
plt.xlim(0,len(y_test))
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot y_test and y_pred as a time series
plt.figure(figsize=(12, 6))
plt.plot((np.arange(len(y_test)))[0:20], (y_test*max(y))[0:20], label="Actual Values (y_test)", color="blue", alpha=0.7)
plt.plot((np.arange(len(y_pred)))[0:20], (y_pred*max(y))[0:20], label="Predicted Values (y_pred)", color="red", alpha=0.7)

# error = y_test + 0.0033

# fig, (ax0, ax1) = plt.subplots(nrows=2, sharex=True)
# ax0.errorbar(x, y, yerr=error)
# 0.0033 
# Add titles and labels
plt.title("Time Series Comparison of Actual vs Predicted Values")
# plt.xlabel("Time Step")
plt.ylabel("Streamflow [m3/s]")
# plt.xlim(0,len(y_test))
plt.legend()
plt.grid(True)
plt.show()

# %%
from scipy.interpolate import make_interp_spline

xnew_test = np.arange(len(y_test))
ynew_test = y_test*max(y)
xnew_pred = np.arange(len(y_pred))
ynew_pred = y_pred*max(y)
X_Y_Spline_Test = make_interp_spline(xnew_test, ynew_test)
X_Y_Spline_Pred = make_interp_spline(xnew_pred, ynew_pred)
# Returns evenly spaced numbers
# over a specified interval.
X_1 = np.linspace(0, xnew_test.max(), 1000)
Y_1 = X_Y_Spline_Test(X_1)
X_2 = np.linspace(0, xnew_pred.max(), 1000)
Y_2 = X_Y_Spline_Pred(X_2)

# Plot y_test and y_pred as a time series
plt.figure(figsize=(12, 6))
plt.plot(X_1,Y_1, label="Actual Values (y_test)", color="blue", alpha=0.7)
plt.plot(X_2,Y_2, label="Predicted Values (y_pred)", color="red", alpha=0.7)


# Add titles and labels
plt.title("Time Series Comparison of Actual vs Predicted Values")
# plt.xlabel("Time Step")
plt.ylabel("Streamflow [m3/s]")
# plt.xlim(0,len(y_test))
plt.legend()
plt.grid(True)
plt.show()

# %%
filename = '/global/scratch/users/arvalcarcel/CSMUB/RESULTS/CNN/rnn_plot.png'
# Ensure the directory exists
os.makedirs(os.path.dirname(filename), exist_ok=True)
from tensorflow.keras.utils import plot_model

# Plot and save the model
plot_model(model, to_file=filename, show_shapes=True, show_layer_names=True)

from IPython.display import Image
Image(filename)

# %%
# import matplotlib.pyplot as plt
# import networkx as nx

# def plot_ffnn(layers):
#     """
#     Plot a simple FFNN structure using Matplotlib.
#     :param layers: List of integers representing the number of neurons in each layer.
#     """
#     G = nx.DiGraph()
#     pos = {}
#     x_offset = 0
    
#     # Build nodes and edges for layers
#     for i, num_neurons in enumerate(layers):
#         y_positions = range(num_neurons)
#         pos.update({(i, j): (x_offset, -y) for j, y in enumerate(y_positions)})
#         x_offset += 1
    
#         # Connect to previous layer
#         if i > 0:
#             for j in range(layers[i-1]):
#                 for k in range(num_neurons):
#                     G.add_edge((i-1, j), (i, k))
    
#     # Draw the graph
#     plt.figure(figsize=(12, 6))
#     nx.draw(G, pos, with_labels=False, node_size=500, node_color="black", edge_color="gray")
#     plt.title("Feed-Forward Neural Network")
#     plt.axis("off")
#     plt.show()


# # model = Sequential([
# #     Dense(256, input_dim=1, activation='relu'),
# #     Dense(128, activation='relu'),
# #     Dense(64, activation='tanh'),
# #     Dense(32, activation='relu'),
# #     Dense(1, activation='linear')  # Output layer
# # ])

# # Example: FFNN with 3 layers: 4 neurons → 6 neurons → 2 neurons
# plot_ffnn([8,6,4,2,1])
